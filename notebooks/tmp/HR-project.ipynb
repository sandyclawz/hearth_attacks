# %% [markdown]
# # Результат ревью:
#
# Я отмечаю адекватный уровень твоей программистской подготовки. Ты используешь продвинутые концепции языка Python, библиотеки pandas и одной из основных библиотек машинного обучения sckit-learn. Это показывает твой уровень владения инструментами анализа данных и machine learning.
#
# С комментированием никаких проблем нет. Твоих объяснений достаточно для понимания твоими коллегами хода мыслей. Ссылки из брифа проекта в нужных местах также помогают следовать за развитием событий и дают полную информацию касаемо того, что будет происходить в том или ином разделе проекта.
#
# Мне было просто проверять твой проект, потому что он чётко структурирован, с использованием оглавления.
#
# Зелёным цветом я отметил и прокомментировал удачные и элегантные решения, на которые ты можешь опираться в будущих проектах.
#
# Жёлтым цветом я выделил то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас.
#
# Красных комментариев, которые бы не позволяли мне принять твой проект в его нынешнем состоянии - нет.
#
# ПРОЕКТ ПРИНЯТ!
#
# Подводя итог: отличная работа, молодец! Желаю тебе успехов в учёбе, желаю, чтобы проекты сдавались или сразу, или после первой итерации! Удачи!
#
# Если же после факта принятия проекта у тебя возникнут дополнительные вопросы – я никуда не пропал. Мой адрес эл/почты: anepomnjashiy@gmail.com, имя в Пачке: anepomnjashiy, имя в Телеграмме: https://t.me/aleks_nep
#
# p.s. я тебе на твой адрес эл/почты сейчас вышлю некоторые материалы из своей электронной библиотеки - надеюсь они будут тебе полезными в учёбе.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Итак, мои комментарии на этот раз будут зелёными, в заголовке иметь версию V2 (как у этого!). Комментарии будут зелеными, даже если в них будут описаны критические ошибки.
#
# Здесь, ниже, по пунктам я эти ошибки перечислю, если таковые будут обнаружены.
#
# Я мелкие/"проходные" изменения/исправления в тексте проекта, каждое из них, не буду с твоего позволения комментировать - но только те моменты, где я что-то более-менее не банальное могу сказать. Хорошо? Будем считать, что, если комментария на твое исправление нет - значит я согласен с тобой в этом пункте.
#
# ---
# Итак, на этой итерации всё-таки остались моменты с прошлого ревью, которые тебе надо исправить. Перечислю их:
#
# 1. (18, 35) Все ли признаки в interval_cols сейчас действительно непрерывные? Или "затесались" в список ещё и дискретные?
#
# Снято много вопросов. Молодец. Остались мелочи. Я их прокомментировал в месте их возникновения (но ты "тетрадку" с самого начала пролистай - в других местах я тоже рабочие комментарии оставлял).
#
# Жду твою работу на повторное ревью.</div>
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Исправил</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V3</b>
#
# Отлично! Смотрю и если всё ОК - сразу принимаю!
# </div>

# %% [markdown]
# Приветствую Сергей!
#
# Меня зовут Александр Непомнящий и я буду проверять твой проект. Предлагаю общаться на «ты» :))) Но, если это не удобно - мы вполне можем перейти на вы".
#
# Вкратце обо мне: я работаю в сфере информационных технологий, аналитика (анализ) данных - это и мой рабочий функционал и личная, интересная мне область для саморазвития. Используемый стек: python, pandas, графические библиотеки matplotlib/seaborn/plotly. Сфера применения: маркетинговая аналитика в медицинской клинике. Если вдруг есть вопрос – что делает аналитик в коммерческой медицине – то вот короткий ответ. Самый главный вопрос, на который мы хотим получить ответ (и который в дальнейшем приведёт к перераспределению рекламного бюджета, плюс напрямую повлияет на разработку и предложению рынку новых лечебных программ) - это КТО ОН, НАШ КЛИЕНТ? Фактически это задача (на нашем внутреннем языке формулируется как построение и анализ «ПОРТРЕТА КЛИЕНТА»). Визуализируем и пытаемся придать смысл половозрастным данным наших клиентов, кто из какого региона и в какие времена года к нам приезжает. Учитываем количество приездов. Учитываем на какую программу этот конкретный клиент приехал в первый раз и как в дальнейшем меняются его предпочтения. Пытаемся построить модель оттока и спрогнозировать, когда клиент уйдёт в отток. Смотрим цифры (суммы трат клиентов на отдельных группах медицинских программ). Анализируем медицинские услуги, которые входят в путёвку, а также что, в каких количествах и на какую сумму клиент покупает дополнительно. Очень вкратце как-то так.
#
# Теперь к сути: основная цель моей проверки - пройти по шагам, по логике твоего решения и обсудить те моменты, которые можно изменить, улучшить, довести до идеала. Такой формат работы двух программистов (аналитиков) ты или уже встречал(а), или встретишь на своей новой работе. Кто-то такой процесс называет "код-ревью", ну а как по мне, так это обмен опытом двух коллег, когда каждый из нас становиться лучше в процессе дискуссии.
#
# Свои мысли, советы, комментарии и вопросы я буду оставлять в текстовых ячейках (markdown) ПОД твоим кодом.
# Для твоего удобства все эти заметки будут "цветными", как на примерах ниже:
#
# "Зелеными" комментариями я буду отмечать твой элегантный ("красивый") код и/или удачные решения, на которые ты можешь смело опираться в будущих проектах.
# <div class="alert alert-success">
# <b>Отлично! 👍</b>
#
# Отличная находка, элегантный код ...</div>
#
# "Жёлтые" комментарии - это мои размышления, предложения, что-то, что на следующей итерации можно сделать по-другому. Твоя реакция на "жёлтые" комментарий необходима и подразумевает или правки, или реакцию или аргументированное согласие/не согласие. Я искренне верю, что наш двусторонний диалог под "желтым" комментарием - это то, от чего твой проект только выиграет. <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Здесь я бы предложил использовать .... Мои аргументы в пользу этого ...</div>
#
# "Красные" комментарий будут появляться, когда что-то пойдёт не так: например, код будет выдавать ошибку. Или, когда в проекте не будет ответов на основные вопросы, ради которых весь анализ и выполнялся. "Красные" комментарии необходимо будет исправить, прежде чем я смогу принять проект.
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# В этой ячейке код работает не так как задумано ...</div>
#
# Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии. Это поможет мне оперативно выполнить повторную проверку твоего проекта.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом, лучше всего в новой ячейке, сразу под моим комментарием. Если для своих комментариев ты будешь использовать какой-то заметный цвет, то мне будет легче отследить твои изменения, например так:
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Текст твоего комментария ...</font>
# </div>
#
# **Распространенные типичные недочёты в проектах студентов:**
#
# <div class="alert alert-danger" ❌>
# Неработоспособный код. Проверь проект на работоспособность перед отправкой на проверку. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании.</div>
# <div class="alert alert-danger" ❌>
# Проект не структурирован. В проекте должна быть структура, т.е. названия разделов и подразделов должны быть записаны в ячейках Markdown.</div>
# <div class="alert alert-warning" 👉 >
# Отсутствие описания, целей проекта, его задач, выводов. В описании должны быть озвучены поставленные задачи, содержание датасета, промежуточные и финальные выводы. Как правило, заказчик читает только финальный вывод, поэтому важно добавить информацию о проведенном исследовании, применить форматирование текста, в общем, сделать красиво, чтобы было понятно, что проведено настоящее исследование и выводу можно верить.</div>
# <div class="alert alert-warning" 👉 >
# "Длинный код". Код и и комментарии, которые прячутся за правым концом ячейки нужно переносить на новую строку. Твои будущие коллеги не оценят необходимость постоянного скроллинга. Согласно PEP8: https://www.python.org/dev/peps/pep-0008/ длина строки не должна превышать 79 символов.</div>
# <div class="alert alert-warning" 👉 >
# Твои коллеги ценят и твое и своё время, поэтому "подсвечивай" свои комментарии в ячейках Markdown. Подробнее про синтаксис Markdown, с примерами, можно почитать здесь: https://paulradzkov.com/2014/markdown_cheatsheet/?
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Приятно познакомиться, Александр! Спасибо за столь подробные и интересные комментарии — думаю, я ещё не раз к ним вернусь, чтобы лучше осмыслить и изучить 8))) Пока на курсе у вас самые обстоятельные и полезные расширенные справочные материалы. Ещё раз спасибо!</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Сергей - приветствую! Всегда рад помочь коллеге!
#
# Сейчас приступаю ко 2ой итерации проверки. Если всё исправлено - сразу приму твой проект!
# </div>

# %% [markdown]
# # Проект: Обучение с учителем — прогнозирование увольнений «Работа с заботой»
#
# ## 🎯 Цель работы
# Оптимизировать управление персоналом за счёт **прогнозирования** уровня удовлетворённости сотрудников и их **намерения уволиться**.
#
# ## 📋 Описание проекта
# HR-аналитики компании «Работа с заботой» помогают бизнесу оптимизировать управление персоналом: бизнес предоставляет данные, а аналитики предлагают меры, которые снижают финансовые потери и отток сотрудников. Для этого используется машинное обучение, чтобы быстрее и точнее отвечать на запросы бизнеса.
#
# Компания предоставила данные по сотрудникам. Среди признаков — **уровень удовлетворённости работой**, рассчитанный по результатам опросника: значение от **0 до 1**, где **0** — полностью неудовлетворён, **1** — полностью удовлетворён.
#
# ## 📊 Ожидаемые результаты проекта
# - **🔎 Построить модель регрессии**, которая предсказывает **уровень удовлетворённости сотрудника** по данным заказчика. Удовлетворённость связана с риском ухода, поэтому её прогноз помогает заранее выявлять проблемные зоны.
# - **🤖 Построить модель классификации**, которая по данным заказчика предсказывает, **уволится ли сотрудник** (факт/вероятность увольнения). Это позволяет заранее оценивать риск внезапных увольнений, особенно среди ключевых сотрудников.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Ты делаешь хорошую работу уже в начале нашего проекта по Data Science. Твой подход к описанию всего проекта уже с самого начала – это плюс. Ты ясно и четко формулируешь цель нашего исследования, что дает нам прочную основу для дальнейших этапов. В реальном проекте выбор метрики для оценки успеха проекта говорил бы о твоем глубоком понимании сути задачи (но здесь, конечно, метрику выбрали авторы задачи за нас).
#
# </div>

# %% [markdown]
# ## Загружаем все модули Python

# %%
#Загружаем все модули
# !pip install phik -q
# !pip -q install shap
# !pip install scikit-learn==1.1.3 -q

#загружаем библиотеки
import pandas as pd
import shap
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import time
#import phik

from IPython.display import display, HTML
from sklearn.linear_model import LinearRegression, LogisticRegression, Ridge
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler
#from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, accuracy_score, confusion_matrix, recall_score, precision_score, precision_recall_curve
from sklearn.metrics import roc_auc_score, make_scorer, RocCurveDisplay
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.datasets import fetch_california_housing
from phik.report import plot_correlation_matrix
from typing import Optional

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.svm import SVC

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Полезный ключ **-q** (он "подавит" служебные сообщения об установке, которых может быть достаточно много - вплоть до нескольких экранов прокрутки).
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Отлично, все импорты собраны в начале "тетрадки"!
#
# ---
# В Python есть своя философия. Именно отсюда берутся определенные правила и стандарты. В пайтон такое соглашение назвали PEP8.
#
# Соответствие PEP8 позволяет видеть основную структуру вашего кода другим разработчикам. Не нужно привыкать к другому оформлению кода. Если вы привыкли как-то оформлять код, а увидели что-то совершенно другое, то вы поймете.
#
# Официальная документация: https://peps.python.org/pep-0008/
#
# Основные моменты и рекомендации:
#
# - Используй пробелы, разрешается использование табов, но смешивание запрещено. Отступ соответствует 4 пробелам. Хорошие редакторы кода автоматически заменяют табы на пробелы.
#
# - Вокруг операторов +, -, =, *, /, ** должны быть пробелы.
#
# - Строка не должна превышать 79 символов
#
# - Ну и наконец про импорты: импорты можно делать только по одному на строку! При этом из одного модуля можно доставать несколько нужных объектов. Порядок тоже важен:
#
# - импорты из стандартной библиотеки
# - импорты из сторонних библиотек
# - импорты пользовательских модулей текущего проекта (например если выносишь функции в отдельный модуль)
#
# И нежелательно их перемешивать с константами и переменными.
#
# p.s. состав стандартных библиотек Python здесь: [The Python Standard Library](https://docs.python.org/3/library/)
# </div>

# %% [markdown]
# ## Задаем константы

# %%
ID_COL = "id"
TARGET = "job_satisfaction_rate"
TARGET_COL = "job_satisfaction_rate"
TARGET_QUIT = "quit"
SAT_COL = "job_satisfaction_rate"
QUIT_COL = "quit"

SPLIT_STRATEGY = "median"   # "median" или "quantile"
Q_LOW, Q_HIGH = 0.33, 0.67

RANDOM_STATE=42

# %% [markdown]
# ## Создаём функции

# %%
# Красиво выводит уникальные значения указанного столбца датафрейма.
def show_unique_values(df, column_name, df_name='DataFrame', emoji='🐮'):
    print(f"{emoji} Уникальные значения в поле '{column_name}' в датафрейме {df_name}:\n")

    unique_vals = pd.unique(df[column_name])

    for i, val in enumerate(unique_vals, 1):
        if pd.isna(val):
            shown = "<NaN>"
        else:
            s = str(val)
            if s.strip() == "":
                shown = "<EMPTY/WHITESPACE>"
            else:
                shown = repr(val)  # покажет кавычки для строк
        print(f"{i:>2}. {shown}")

    print(f"\nВсего уникальных значений: {len(unique_vals)}\n-------------\n")
    
def compare_categorical_overlay(train: pd.DataFrame, test: pd.DataFrame, col: str):
    # фильтруем строки с NaN в анализируемом столбце
    train_f = train.loc[train[col].notna(), [col]].copy()
    test_f  = test.loc[test[col].notna(), [col]].copy()

    tr = train_f[col].astype(str).str.strip().str.lower().value_counts(dropna=False)
    te = test_f[col].astype(str).str.strip().str.lower().value_counts(dropna=False)

    comp = pd.DataFrame({"train": tr, "test": te}).fillna(0).astype(int)
    comp["train_%"] = (comp["train"] / comp["train"].sum() * 100).round(2)
    comp["test_%"]  = (comp["test"]  / comp["test"].sum()  * 100).round(2)
    comp = comp.sort_values("train_%", ascending=False)

    display(comp)

    x = np.arange(len(comp.index))
    width = 0.45

    plt.figure(figsize=(10, 5))
    plt.bar(x - width/2, comp["train_%"].values, width=width, label="train")
    plt.bar(x + width/2, comp["test_%"].values,  width=width, label="test")
    plt.title(f"Распределение по '{col}' (доли, %), NaN исключены")
    plt.xlabel(col)
    plt.ylabel("share, %")
    plt.xticks(x, comp.index.astype(str), rotation=45, ha="right")
    plt.legend()
    plt.tight_layout()
    plt.show()


def compare_numeric_overlay(train: pd.DataFrame, test: pd.DataFrame, col: str, bins: int = 30):
    # фильтруем NaN
    tr = train.loc[train[col].notna(), col].astype(float)
    te = test.loc[test[col].notna(), col].astype(float)

    all_vals = pd.concat([tr, te], axis=0)
    edges = np.histogram_bin_edges(all_vals, bins=bins)

    plt.figure(figsize=(9, 4))
    plt.hist(tr, bins=edges, density=True, histtype="step", linewidth=2, label="train")
    plt.hist(te, bins=edges, density=True, histtype="step", linewidth=2, label="test")
    plt.title(f"Наложение распределений '{col}' (плотность), NaN исключены")
    plt.xlabel(col)
    plt.ylabel("density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(9, 2.8))
    plt.hist(tr, bins=edges, density=True, histtype="step", linewidth=2, label="train")
    plt.hist(te, bins=edges, density=True, histtype="step", linewidth=2, label="test")
    plt.axvline(tr.mean(), linestyle="--", linewidth=1, label="train mean")
    plt.axvline(tr.median(), linestyle=":", linewidth=1, label="train median")
    plt.axvline(te.mean(), linestyle="--", linewidth=1, label="test mean")
    plt.axvline(te.median(), linestyle=":", linewidth=1, label="test median")
    plt.title(f"'{col}': наложение + mean/median, NaN исключены")
    plt.xlabel(col)
    plt.ylabel("density")
    plt.legend(ncol=2)
    plt.tight_layout()
    plt.show()
    
def make_group_col(y: pd.Series, strategy: str = SPLIT_STRATEGY,
                   q_low: float = Q_LOW, q_high: float = Q_HIGH) -> pd.Series:
    y = y.astype(float)

    if strategy == "quantile":
        lo, hi = y.quantile(q_low), y.quantile(q_high)
        return pd.Series(np.where(y <= lo, "низкая", np.where(y >= hi, "высокая", "средняя")), index=y.index)

    m = y.median()
    return pd.Series(np.where(y <= m, "низкая", "высокая"), index=y.index)


def analyze_train_like_example(train: pd.DataFrame,
                               target: str = TARGET,
                               id_col: str = ID_COL,
                               cat_cols_manual: Optional[list] = None):

    # 1) оставляем строки, где target не NaN
    df = train.loc[train[target].notna()].copy()
    df["group"] = make_group_col(df[target])

    # 2) списки столбцов
    num_cols = df.select_dtypes(include="number").columns.drop([id_col, target], errors="ignore").tolist()

    if cat_cols_manual is None:
        cat_cols = df.select_dtypes(include=["object", "string"]).columns.drop("group", errors="ignore").tolist()
    else:
        cat_cols = cat_cols_manual

    # 3) Числовые: медианы (NaN автоматически игнорируются в median)
    med = df.groupby("group")[num_cols].median().T

    # сравниваем "низкая" vs "высокая" если есть, иначе первые две
    cols = med.columns.tolist()
    if "низкая" in cols and "высокая" in cols:
        g1, g2 = "низкая", "высокая"
    else:
        g1, g2 = cols[:2]

    med["Изменение, %"] = ((med[g2] - med[g1]) / med[g1]) * 100
    med_show = med.copy()
    med_show["Изменение, %"] = med_show["Изменение, %"].round(1).astype(str) + "%"

    print(f"Медианы числовых признаков (сравнение: '{g1}' -> '{g2}'):")
    display(med_show.round(2))
    print("\n--------------------------------------------------------------\n")

    # 4) Категориальные: сразу исключаем NaN по текущему признаку
    base, comp = ("высокая", "низкая") if {"низкая","высокая"}.issubset(df["group"].unique()) else (g2, g1)

    for c in cat_cols:
        tmp = df.loc[df[c].notna(), [c, "group"]].copy()  # <-- фильтр NaN одной строкой

        ct = pd.crosstab(tmp[c], tmp["group"], normalize="columns") * 100
        if base in ct.columns and comp in ct.columns:
            ct["Отклонение, п.п."] = ct[base] - ct[comp]

        ct_str = ct.round(1).astype(str)
        if base in ct.columns: ct_str[base] = ct[base].round(1).astype(str) + "%"
        if comp in ct.columns: ct_str[comp] = ct[comp].round(1).astype(str) + "%"
        if "Отклонение, п.п." in ct.columns:
            ct_str["Отклонение, п.п."] = ct["Отклонение, п.п."].round(1).astype(str) + " п.п."

        display(ct_str)
        
# Логи/тайминг
def step(msg: str):
    print(f"\n--- {msg} ---")

def timed(label, fn, *args, **kwargs):
    t0 = time.perf_counter()
    out = fn(*args, **kwargs)
    dt = time.perf_counter() - t0
    print(f"[TIME] {label}: {dt:.2f} sec")
    return out

def get_feature_names_quit(preprocess):
    names = []

    for block_name, trans, cols in preprocess.transformers_:
        if block_name == "remainder" or trans == "drop":
            continue

        cols = list(cols) if not isinstance(cols, slice) else []

        # num/ord — просто имена колонок
        if block_name in ("num", "ord"):
            names.extend(cols)

        # ohe — берём имена из OneHotEncoder
        elif block_name == "ohe":
            enc = None
            if hasattr(trans, "named_steps"):
                enc = trans.named_steps.get("encoder", None)

            if enc is not None and hasattr(enc, "get_feature_names_out"):
                names.extend(enc.get_feature_names_out(cols).tolist())
            else:
                names.extend(cols)

        else:
            names.extend(cols)

    return np.array(names, dtype=object)


def to_dense(X):
    return X.toarray() if hasattr(X, "toarray") else np.asarray(X)


def report_duplicates(
    df: pd.DataFrame,
    name: str,
    id_col: str = "id",
    target_col: Optional[str] = "job_satisfaction_rate",
    show_examples: bool = False,
    n_examples: int = 10
):
    print(f"\n{name}")
    print("-" * 60)

    # 1) полные дубли
    full_dups = df.duplicated().sum()
    print(f"Полные дубликаты строк: {full_dups}")

    # 2) дубли без id (если id есть)
    if id_col in df.columns:
        no_id_dups = df.drop(columns=[id_col]).duplicated().sum()
        print(f"Дубликаты без '{id_col}': {no_id_dups}")
    else:
        print(f"Колонки '{id_col}' нет — пропускаем проверку без id.")

    # 3) "смысловые" дубли по subset (без id и без таргета)
    drop_cols = [id_col] + ([target_col] if (target_col is not None and target_col in df.columns) else [])
    subset_cols = [c for c in df.columns if c not in drop_cols]

    if subset_cols:
        subset_dups = df.duplicated(subset=subset_cols).sum()
        tgt_txt = target_col if (target_col is not None and target_col in df.columns) else "—"
        print(f"Дубликаты по subset (без '{id_col}' и '{tgt_txt}'): {subset_dups}")
        print(f"subset cols ({len(subset_cols)}): {subset_cols}")

        if show_examples and subset_dups > 0:
            d = df[df.duplicated(subset=subset_cols, keep=False)].sort_values(subset_cols)
            print(f"\nПримеры 'смысловых' дублей (первые {n_examples} строк):")
            display(d.head(n_examples))
    else:
        print("subset_cols пустой — пропускаем subset-проверку.")
        
def compare_discrete_counts(dfs: dict, col: str, figsize=(12, 4)):
    # общий порядок значений по всем датафреймам
    order = sorted(set().union(*[
        set(df[col].dropna().unique()) for df in dfs.values() if col in df.columns
    ]))

    comp = pd.DataFrame({
        name: df[col].value_counts().reindex(order, fill_value=0) if col in df.columns else 0
        for name, df in dfs.items()
    })

    x = np.arange(len(order))
    k = len(comp.columns)
    width = min(0.8 / max(k, 1), 0.35)

    plt.figure(figsize=figsize)
    for i, name in enumerate(comp.columns):
        plt.bar(x - 0.4 + width/2 + i*width, comp[name].values, width=width, label=name)

    plt.xticks(x, [str(v) for v in order])
    plt.xlabel(col)
    plt.ylabel("count")
    plt.title(f"{col}: сравнение распределений")
    plt.legend()
    plt.tight_layout()
    plt.show()

    display(comp)

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
#
# Отлично! Красивые функции. Ну и здорово что ты понимаешь, что применение функций упрощает код, делает его структурированным, простым для понимания и упрощает его дальнейшее переиспользование (принцип DRY (Don’t Repeat Yourself / Не повторяйся) – в действии). Дополнительно о DRY можно почитать здесь: https://habr.com/ru/company/itelma/blog/546372
#
# </div>

# %% [markdown]
# # Задача 1: предсказание уровня удовлетворённости сотрудника

# %% [markdown]
# ## Шаг 1. Загрузка данных

# %% [markdown]
# ### 🎯 Задачи шага
#
# 1) Загрузите файлы с данными:
#
# - **Тренировочная выборка:** `train_job_satisfaction_rate.csv`
# - **Входные признаки тестовой выборки:** `test_features.csv`
# - **Целевой признак тестовой выборки:** `test_target_job_satisfaction_rate.csv`

# %%
train = pd.read_csv('/datasets/train_job_satisfaction_rate.csv', sep=',', decimal='.')
test_features = pd.read_csv('/datasets/test_features.csv', sep=',', decimal='.')
test_target = pd.read_csv('/datasets/test_target_job_satisfaction_rate.csv', sep=',', decimal='.')

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Отлично. Импортировали требуемые для анализа библиотеки и загрузили данные. Сейчас посмотрим на их состояние и если всё ОК, сможем приступать к построению моделей....
#
# p.s. при установке дополнительных библиотек (через ! pip install ...) можно использовать полезный ключ **-q** (он "подавит" служебные сообщения об установке, которых может быть достаточно много - вплоть до нескольких экранов прокрутки)
#
# p.p.s. При считывании данных из файла здорово перестраховывать себя от ошибок, связанных, например, с неверным указанием пути к файлу. А иногда бывает, что работаешь с файлом локально, выгружаешь его на сервер, ожидая, что он будет принимать данные, которые лежат на том же сервере, а код падает с ошибкой, потому что путь к файлу не поменялся с локального на серверный.
#
# Для этого, например, можно использовать конструкцию `try-except`: сначала пробуешь локальный путь, при возникновении ошибки используется серверный путь (подробнее можешь почитать тут: https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html).
#
# Но еще лучше использовать библиотеку `os` - её использование позволит тебе проверять существование указанных директорий (что может быть актуально при одновременной работа на локальном и сетевом окружении) и загружать данные из существующей директории, избегая ошибок. Как пример:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# Ещё на этапе считывания данных можно спарсить дату: за это действие отвечает параметр `parse_dates` метода `read_csv()`, в него нужно передать список с названием полей-дат, и в большинстве случаев дата будет корректно преобразована в нужный формат сразу:)
# Также на этапе считывания данных задать индекс-столбец- за это действие отвечает параметр `index_col`.
# </div>

# %%
display(train.head(5))

print("===== train - Тренировочная выборка ===== \n")
print(train.info(), "\n")
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  155278       sales  junior   medium                 2              no
# 1  653870          hr  junior     high                 2              no
# 2  184592       sales  junior      low                 1              no
# 3  171431  technology  junior      low                 4              no
# 4  693419          hr  junior   medium                 1              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      1   24000                   0.58
# 1                   no                      5   38400                   0.76
# 2                   no                      2   12000                   0.11
# 3                   no                      2   18000                   0.37
# 4                   no                      3   22800                   0.20
# ===== train - Тренировочная выборка =====
#
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Да, верно, info() показывает, что в небольшом числе столбцов данных нашего датафрейма есть пропуски. Не хорошо, не хорошо ... придётся эти моменты отрабатывать. Пишу "нехорошо" потому, что при кажущейся простоте задачи - обработка пропусков таит в себе массу вопросов как технического плана, так и организационного момента, бизнес-аспекта и даже вопросы этического плана (ниже будет моё эссе на эту тему - где я попытался раскрыть сложность вопроса).
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# По результатам проверки 5,4 тысяч проектов за последние 3,5 года у меня родилось небольшое эссе на тему "удаления vs. спасения" данных, как раз на основе тех ситуаций и вопросов, которые мне коллеги задавали, которые мы обсуждали, уточняли и исправляли ...
#
# <br>
# <br>
# <details>
# <summary style="color: blue; font-size: 18px; font-weight: bold;">▶ <u>Подробнее ...</u></summary>
#
# Желание уменьшить количество пропусков в данных (если такое желание конечно возникает ... но в рабочих проектах, "в жизни" оно как правило возникает) - можно только приветствовать. Приветствовать по 3-м минимум причинам:
#
# 1. это тренировка
#
# 2. это попытка сохранить данные ("данных много не бывает")
#
# 3. самое главное на мой взгляд - развитие аналитического мышления, желания "проникать" в секреты, которые скрывают данные. Когда вначале рождается гипотеза, потом эта гипотеза проверяется на данных (может ли такое быть? подтверждается?) и в финале уже гипотеза облекается в код.
#
# Однако заполнение пропусков в данных не такая простая задача, как кажется ... простого ответа на вопросы: заполнять? удалить? чем заполнять? подходящего под все сценарии, нет ни в одной умной книжке ...
#
# Самый идеальный случай - когда у тебя под рукой есть эксперт в предметной области. Если такой есть - советуйся с ним. Как правило это человек из бизнеса, который знает суть бизнес-процесса и вот именно он даст тебе точный и аргументированный совет - что в данной, конкретной задаче делать с "битыми" полями в строках датафрейма. Ты скажешь ему какой процент пропусков в данных, а он тебе ответит что делать: можно/нельзя удалить и/или даст рекомендации по заполнению. Вообще, как правило такой человек "на любой работе" есть. Для примера, финансовый директор думаю всегда даст рекомендации по финансовым данным, прочие профильные спецы - по своей сфере компетенций. Наверное только в зарождающемся стартапе может не быть каких-то компетенций, но тут уже можно и через фриланс (и т.п.) попробовать найти спеца и просить совета.
#
# Теперь, что делать, если такого человека нет. Я бы ответил так: **ПОПЫТАТЬСЯ** вникнуть в бизнес-проблему самому. Наверное это сложно, если предметная область ну совсем незнакома. Но в общем случае, если бизнес совсем незнаком, то заполнение пропусков в данных наверное, не получиться. В таком случае попробуй ориентироваться на такое правило: если записи с пропусками в ключевых для твоего анализа столбцах составляют 1-3-5-ну может до 10% строк, то попробуй эти записи из оригинального датафрейма вырезать (но сохрани бы в некий df, к которому ты при необходимости можешь всегда обратиться).
#
# В жизни, МНЕ КАЖЕТСЯ, как правило по всему датафрейму заполнять медианой/средним - ну вообще не вариант. Почему? Я бы ответил так - потому, что реальные датафреймы имеют миллионы строк и горизонт в несколько (десятков) лет, и если в 90-2000-е года всё было как-то более -менее стабильно/прогнозируемо, то в нынешней реальности события раскручиваются гораздо быстрее и не прогнозируемо. Пример: ты аналитик в автобизнесе. У тебя есть данные с пропусками в цене для машин в 2005-2007 года. Можно заполнить их средними основываясь на данных 2020-2021?
#
# Может быть и такой вариант, что без заполнения некоторых столбцов некоторые записи по сути **НЕ** имеют смысла, но если их (записи с пропусками удалить), то и данных-то не останется. Ну тогда я бы такой совет дал - всё же заполнять медианой (она к скачкам выбросов более устойчива), но не по всему глобальному датафрейму, а выбрать простые группы (например, группы по интервалу лет - чтобы сгладить турбулентность нынешних лет) или выбрать более сложные группы (например, группы по интервалу лет и одновременно марке автопроизводителя (это я про вымышленный пример с автобизнесом)).
#
# Теперь предположим, что мы выбрали какую-то стратегию заполнения "пропусков", не суть какую (оставить NaN или заполнить "заглушкой"). И в том и в другом случае придётся помнить этот выбор. Ты спросишь почему? Отвечу - потому, что инструменты, применяемые тобой в Питон/Пандас в каких-то случаях могут спокойно пропускать твой выбор, а в каких-то случаях тебе придется этот твой выбор обрабатывать.
#
# Пример 1: мы заполнили пропуски "заглушкой". В этом случае: 1. расчет корреляций значение "заглушку" будет "ловить" (надо отфильтровать!), 2. расчет гипотез также будет "сбивать" правильный вывод (надо отфильтровать!) 3. графики, которые ты будешь строить - будут "заглушку" отображать на осях (нужно фильтровать), 4. в группировках также по-видимому "заглушку" надо будет убирать.
#
# Пример 2: мы оставили пропуски как NaN. В этом случае: 1. метод .corr NaN'ы пропускает (отфильтровать не надо), 2. в расчет гипотез всё равно пропуски отфильтровать 3. графики, которые ты будешь строить могут отображать, а могут не отображать, 4. в группировках NaN'ы по sum() видны не будут, а по count() будут.
#
# Ну и напоследок совсем уже жёсткий пример: додумывать "от себя", бездумно проставлять в пропуски медианные/средние значения - это НЕ верно. Давай же опять "про жизнь". Я писал выше, что в медицине работаю, да? **Предположим** мне принесли данные из онкологического диспансера. Задача: построить модель, которая по некоторым маркерным анализам будет прогнозировать наличие онкологии. **По-простому, ответить, что стоит за строчкой в данных: жизнь или смерть.** Уууууух … аж мороз по коже продирает, правда?
#
# Итак, 1.000.000 записей и 70 столбцов. Данные за 25 лет. 70 столбцов - это поля, с результатами конкретных и очень специфичных анализов. В "начале" данных, 15-20 лет назад, есть пропуски (много), но и в принципе, в данных есть пропуски. Как думаешь - имею я моральное право перед людьми, которые фактически доверяют мне в виде данных свою жизнь огульно подойти к заполнению пропусков?
#
# </details>
# <br>
# <br>
# </div>

# %%
display(test_features.head(5))

print("===== test_features - Входные признаки тестовой выборки: ===== \n")
print(test_features.info(), "\n")
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary
# 0                   no                      5   28800
# 1                   no                      4   30000
# 2                   no                      4   19200
# 3                   no                      4   19200
# 4                   no                      5   40800
# ===== test_features - Входные признаки тестовой выборки: =====
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
# ...

# %%
display(test_target.head(5))

print("===== test_target - Целевой признак тестовой выборки:: ===== \n")
print(test_target.info(), "\n")
# Out:
#        id  job_satisfaction_rate
# 0  130604                   0.74
# 1  825977                   0.75
# 2  418490                   0.60
# 3  555320                   0.72
# 4  826430                   0.08
# ===== test_target - Целевой признак тестовой выборки:: =====
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB
# None

# %% [markdown]
# ### 📋 Выводы этапа «Загрузки данных»
#
# - Загрузили **тренировочную выборку**, **входные признаки тестовой выборки** и **целевой признак тестовой выборки** в отдельные датафреймы.
# - Проверили, что данные соответствуют описанию: структура таблиц корректна, признаки и целевой столбец находятся в ожидаемых файлах.
#
# ***Общая оценка***: предложенный для анализа датасет — качественный и соответствует внутренней аналитике.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Хорошо, данные загрузили, первичные проверки сделали.
# </div>

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %% [markdown]
# ### 🎯 Задачи шага
#
# Проведите необходимую предобработку данных.

# %% [markdown]
# <div style="
#     background:#f2f2f2;
#     border:1px solid #d9d9d9;
#     padding:10px 12px;
#     border-radius:8px;
#     font-size:16px;
#     line-height:1.4;">
#   <b>Сделаем следующие шаги:</b>
#   <ul style="margin:8px 0 0 18px;">
#     <li>Название колонок и типы нормальные. Но есть пропуски данных согласно информации по датафреймам. Оставим их и обработаем их в pipeline</li>
#       <li>Проверим на уникальность категориальных значений</li>
#   </ul>
# </div>

# %%
#Проверим и выведем количество пропусков по столбцам и число полных дубликатов
#для каждого датафреймов.

dfs = {
    "train": train,
    "test_features": test_features,
    "test_target": test_target
}

for name, df in dfs.items():
    print(f"Пропуски в {name}:")
    print(df.isna().sum(), "\n")
    print(f"Дубликатов в {name}: {df.duplicated().sum()}")
    print("-" * 60)
# Out:
# Пропуски в train:
# id                       0
# dept                     6
# level                    4
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# job_satisfaction_rate    0
# dtype: int64
#
# Дубликатов в train: 0
# ------------------------------------------------------------
# Пропуски в test_features:
# id                       0
# dept                     2
# level                    1
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# dtype: int64
#
# Дубликатов в test_features: 0
# ------------------------------------------------------------
# Пропуски в test_target:
# id                       0
# job_satisfaction_rate    0
# dtype: int64
#
# Дубликатов в test_target: 0
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Хочу отметить, что в общем случае даже если **df.duplicated().sum() == 0** - это может совсем не означать, что в данных нет дубликатов.
#
# ---
# В реальных рабочих датасетах скорее всего не будет полных дубликатов, но вот неявные наверняка будут встречаться, соответственно с ними надо будет уметь работать. Для поиска неявных дублей обычно используют параметр **subset** у функции duplicated(). Правда здесь, в нашем проекте, надо поразмыслить над тем какие комбинации столбцов могут говорить о реальных дублях в данных.
#
# p.s. **ВАЖНО: признак id не должен передаваться в модели МО (он не информативный). Поэтому после его удаления (или "перевода" в индекс)  следует ещё раз поискать дубликаты в данных**.
# </div>
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Протестировал функцию по поиску неявных и смысловых дупликатов</font>
# </div>

# %%
report_duplicates(train, "train", id_col="id", target_col="job_satisfaction_rate")
report_duplicates(test_features, "test_features", id_col="id", target_col="job_satisfaction_rate")
# Out:
# train
# ------------------------------------------------------------
# Полные дубликаты строк: 0
# Дубликаты без 'id': 245
# Дубликаты по subset (без 'id' и 'job_satisfaction_rate'): 1492
# subset cols (8): ['dept', 'level', 'workload', 'employment_years', 'last_year_promo', 'last_year_violations', 'supervisor_evaluation', 'salary']
#
# test_features
# ------------------------------------------------------------
# Полные дубликаты строк: 0
# Дубликаты без 'id': 557
# Дубликаты по subset (без 'id' и '—'): 557
# subset cols (8): ['dept', 'level', 'workload', 'employment_years', 'last_year_promo', 'last_year_violations', 'supervisor_evaluation', 'salary']

# %%
# какие столбцы чистим (все object)
train_obj_cols = train.select_dtypes(include=["object"]).columns
test_obj_cols  = test_features.select_dtypes(include=["object"]).columns

def empty_to_nan(df, cols):
    df = df.copy()
    for c in cols:
        s = df[c].astype(str).str.strip()
        df.loc[s.eq("") | s.str.lower().eq("nan"), c] = np.nan
    return df

train = empty_to_nan(train, train_obj_cols)
#test_features = empty_to_nan(test_features, test_obj_cols)

# %%
# исправляем опечатку в уровне: sinior -> senior
#train["level"] = train["level"].astype("string").str.strip().str.lower().replace({"sinior": "senior"})
#test_features["level"] = test_features["level"].astype("string").str.strip().str.lower().replace({"sinior": "senior"})

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# ![image.png](attachment:image.png)
#
# Для test выборки значения (ни пропуски, ни дубликаты, ни ошибки) удалять/обрабатывать "вручную" нельзя - эта выборка имитирует реальный поток, в котором модели нужно будет работать со всеми наблюдениями. Ты в приницпе, в реальной жизни, не знаешь какие данные поступят "на вход" разработанной тобой модели (а эти данные, которые будут поступать и по которым твоя модель должна отработать и сделать predict и есть полный аналог тестовой выборки).
#
# Пропуски и ошибки (если они поступают "на вход" ML-модели) **следует обработать в пайплайне**, настроив соответствующим образом работу кодировщиков для новых значений в признаках.
#
# Дубликаты (если они поступают "на вход" ML-модели) - это записи по которым твоя модель должна сделать предсказания.
#
# Да, да, да, это тестовая выборка. С ней работает **только** модель. Удалить/исправить она ничего не может в её данных, но выполнить transform и сделать predict - может. Ну а если в модели корректно сконфигурированы кодировщики (например OneHotEncoder / OrdinalEncoder), то обработка некоторых гипотетических "ошибок" в тестовой выборке и так будет выполнена.
# </div>
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Убрал чистку данных</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Исправлено.
# </div>

# %%
# Перебор всех датафреймов из dfs и вывод уникальных значений для всех object-столбцов

dfs = {
    "train": train,
    "test_features": test_features,
    "test_target": test_target
}

for df_name, df in dfs.items():
    obj_cols = df.select_dtypes(include=["object"]).columns.tolist()
    if not obj_cols:
        continue

    for col in obj_cols:
        show_unique_values(df, col, df_name=df_name, emoji="🧾")
# Out:
# 🧾 Уникальные значения в поле 'dept' в датафрейме train:
#
#  1. 'sales'
#  2. 'hr'
#  3. 'technology'
#  4. 'purchasing'
#  5. 'marketing'
#  6. <NaN>
#
# Всего уникальных значений: 6
# -------------
#
# 🧾 Уникальные значения в поле 'level' в датафрейме train:
#
#  1. 'junior'
#  2. 'middle'
#  3. 'sinior'
#  4. <NaN>
#
# Всего уникальных значений: 4
# -------------
#
# 🧾 Уникальные значения в поле 'workload' в датафрейме train:
#
#  1. 'medium'
#  2. 'high'
#  3. 'low'
#
# Всего уникальных значений: 3
# -------------
#
# 🧾 Уникальные значения в поле 'last_year_promo' в датафрейме train:
#
#  1. 'no'
#  2. 'yes'
#
# Всего уникальных значений: 2
# -------------
#
# 🧾 Уникальные значения в поле 'last_year_violations' в датафрейме train:
#
#  1. 'no'
#  2. 'yes'
#
# Всего уникальных значений: 2
# -------------
#
# 🧾 Уникальные значения в поле 'dept' в датафрейме test_features:
#
#  1. 'marketing'
#  2. 'hr'
#  3. 'sales'
#  4. 'purchasing'
#  5. 'technology'
#  6. <NaN>
# ...

# %% [markdown]
# ### 📋 Выводы этапа «Предобработка данных»
#
# - Проверили категориальные значения во всех таблицах на уникальность и ошибки

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# **Хочу "подсветить" критическую важность этого раздела**. Важность и здесь, в учебном проекте, важность и в реальных исследованиях (на реальных данных, на реальной работе).
#
# Пример из моей практики: мы, в Клинике, с 2018 года занимаемся аналитикой и порой даже сейчас находим закономерности, тренды, инсайты и корреляции в наших данных. У нас данные конечно не такие большие (50 тысяч записей (50.000 х 70+ признаков) о клиентах + 10 миллионов записей (10.000.000 х 20+ признаков) о результатах выполненных ими медицинских процедур, как в реальной big data, но тем не менее труда в изучение данных вложено немало ... И ты знаешь, изучение данных даёт свой результат!
#
# **Я сейчас ввиду критической важности EDA для финального результата любого DA/ML/DS проекта приведу последовательный чеклист с шагами которого ты можешь сверяться и в этом проекте и во всех следующих (и учебных и рабочих)**:
#
# 1. Загружаем данные,
#
# 2. Выполняем head(), смотрим на результат info(), анализируем аномалии (describe()),
#
# 5. Делаем анализ дубликатов и пропусков,
#
# 6. Фильтрация (уточнение) данных - если для выполнения проектной задачи требуется не весь датафрейм, а какой-то срез из данных,
#
# 5. Строим графики **для всех признаков**: гистограммы для непрерывных признаков, sns.countplot - для дискретных,
#
# 6. "Рисуем" боксплоты ("ящики с усами") для непрерывных признаков,
#
# 7. Визуализируем Q-Q плоты (для проверки признаков на нормальность) и/или статистические тесты,
#
# 8.  После выполнения анализа можем приступить к обоснованному заполнению пропусков в данных (или также обоснованному удалению записей с пропусками из данных). Следует обратить внимание, что если пропуски заполняем, то будем использовать не "глобальную" (по всему набору данных) медиану/среднее, а значения рассчитанные по обучающей выборке (иначе будет "утечка" данных в тестовую выборку).
# </div>

# %% [markdown]
# ### 🎯 Задачи шага
#
# * Проведем сравнение в тестовых и тренировочных данных

# %%
# --- применяем ---
for col in ["dept", "workload"]:
    compare_categorical_overlay(train, test_features, col)

for col in ["salary"]:
    compare_numeric_overlay(train, test_features, col, bins=30)
# Out:
#             train  test  train_%  test_%
# sales        1512   763    37.86   38.19
# technology    866   455    21.68   22.77
# purchasing    610   273    15.27   13.66
# marketing     550   279    13.77   13.96
# hr            456   227    11.42   11.36
#                 0     1     0.00    0.05
#         train  test  train_%  test_%
# medium   2066  1043    51.65   52.15
# low      1200   593    30.00   29.65
# high      734   363    18.35   18.15
#             0     1     0.00    0.05

# %%
dfs = {"train": train, "test_features": test_features}
compare_discrete_counts(dfs, "employment_years")
compare_discrete_counts(dfs, "supervisor_evaluation")
# Out:
#     train  test_features
# 1     966            522
# 2     785            374
# 3     483            234
# 4     384            187
# 5     380            179
# 6     287            138
# 7     301            174
# 8     193             91
# 9     130             66
# 10     91             35
#    train  test_features
# 1    201             88
# 2    387            196
# 3   1263            575
# 4   1603            857
# 5    546            284

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Просто супер: графики подписаны, оси подписаны. Не часто на самом деле такой скрупулёзный подход к оформлению встречается. Молодец!
#
# Я закончил физико-математический факультет Петрозаводского государственного университета. Нас там с первого курса приучили - если на сдачу лабораторной работы по физике приходишь с графиком, на котором не подписано общее название, названия осей (с единицами измерений), единичная шкала - всё сдача заканчивается не начавшись. Или если у моей лабораторной работы отсутствует вывод: что делали? по какой методике? что "намеряли"? как интерпретировали? какой финальный вывод? - всё, тоже на выход. Ну и в принципе сейчас, на текущей работе: код, который написан в тетрадке мало кому понятен и не сильно кому интересен. Важнее детальные выводы и тренды, которые попадут на слайд презентации в PowerPoint. Именно поэтому столь важное значение в аналитике данных придается промежуточным выводам и уж тем более финальному.
#
# ---
# (МЕТОДИЧЕСКИЕ МАТЕРИАЛЫ ПО ОФОРМЛЕНИЮ ГРАФИКОВ):
#
# При работе с графиками важно соблюдать следующие правила:
#
# 1. Стоит подписать названия осей X и Y.
#
# 2. Также стоит дать название графику.
#
# 3. Технические комментарии типа `<AxesSubplot:xlabel='datetime'>` стоит убирать - это можно сделать, поставив точку с запятой в последней строке кода в блоке визуализации, либо сделать последней строкой кода этого блока метод plt.show().
#
# 4. Графики нужно сделать больше - графики дефолтного размера не очень удобны для чтения. Удобнее будет настроить параметр plt.rcParams["figure.figsize"] = (x,y) сразу в ячейке импорта библиотек, и все графики проекта будут одного размера.
#
# Несколько таких нехитрых приёмов повысят качество твоих визуализаций в проекте. **И здесь следует сказать что ты об правилах оформления всё знаешь! МОЛОДЕЦ!**
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
#
#
# Ряд признаков в наших данных имеет дискретную природу (например это **employment_years** и **supervisor_evaluation**). Для графического анализа дискретных признаков нужнен тип графиков, который на каждое уникальные значение признака строит свою корзину. Например, можно использовать **sns.countplot** или **.plot(kind='bar')**. Ты же для визуализации их используешь гистограмму.
#
# ---
# Гистограммы обычно хорошо подходят для визуализации распределения непрерывных числовых признаков. Это могут быть такие признаки, как возраст, доход, количество продуктов в корзине, и т.д. Гистограммы помогают наглядно представить, как значения признака распределены по диапазону.
#
# Для дискретных признаков, особенно если их значения ограничены и могут быть перечислены (например, категории, группы), столбчатые диаграммы или другие методы визуализации, такие как круговые диаграммы или ящики с усами, могут быть более подходящими.
#
# Конечно, если у тебя есть дискретный признак, который принимает большое количество разных значений, и ты хочешь понять их распределение, ты можешь попробовать использовать гистограмму, но при этом учти, что столбцы будут разреженными и могут не давать полного представления о распределении.
#
# **Важно подбирать подходящий тип графика в зависимости от природы данных и целей визуализации.**
# </div>
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Добавил отдельный вывод дискретных значений</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Исправлено.
# </div>

# %%
def pie_train_test_binary(train: pd.DataFrame, test: pd.DataFrame, col: str, title: str = None):
    tr = train[col].astype(str).str.strip().str.lower().value_counts(dropna=False)
    te = test[col].astype(str).str.strip().str.lower().value_counts(dropna=False)

    fig, axes = plt.subplots(1, 2, figsize=(10, 5))

    axes[0].pie(tr.values, labels=tr.index.astype(str), autopct="%1.1f%%")
    axes[0].set_title(f"{title or col} (train)")

    axes[1].pie(te.values, labels=te.index.astype(str), autopct="%1.1f%%")
    axes[1].set_title(f"{title or col} (test)")

    plt.tight_layout()
    plt.show()

# Повышения
pie_train_test_binary(train, test_features, "last_year_promo", title="Доля повышений за последний год")

# Наказания / нарушения
pie_train_test_binary(train, test_features, "last_year_violations", title="Доля нарушений за последний год")

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Использование pie-диаграмм для анализа категориальных признаков - отлично!
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
#
#
# Специалисты по визуализации утверждают, что наш мозг?/глаз? **очень плохо "различает различия"** между "примерно одинаковыми" кусочками pie-диаграммы. Ну и соответственно рекомендуют использовать столбиковые?/столбцовые? диаграммы. У тебя конечно цифрами "кусочки" подписаны, но тем не менее мнение такое в среде специалистов по визуализации существует.
#
# Я ни в коем случае не против pie-диаграмм! Я просто призываю помнить об их обманчивой сущности )))
#
# p.s. по факту приёма проекта я пришлю тебе набор книг в котором среди прочих будут и книги по визуализации.
#
# </div>

# %% [markdown]
# <div style="
#     background:#f2f2f2;
#     border:1px solid #d9d9d9;
#     padding:10px 12px;
#     border-radius:8px;
#     font-size:16px;
#     line-height:1.4;">
#     <b>Данные в тестовых и тренировочных данных однотипны</b>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
#
#
# Да, трейн похож на тест.
#
# И да, и это важно для нашей лучшей модели МО. Значит будучи обученной на трейне - она будет "предсказывать" корректно (т.к. тест и трейн похожи, наверняка взяты из одного распределения).
# </div>

# %% [markdown]
# ### 📋 Выводы по сравнению train и test
#
# **1) Состав сотрудников по департаментам (dept)**
# - Распределения **почти совпадают** между train и test: доминирует **sales (~38%)**, далее **technology (~22%)**, затем **purchasing (~14–15%)**, **marketing (~14%)**, **hr (~11%)**.
# - Отличия минимальные: в test немного **больше technology** и немного **меньше purchasing** (в пределах пары п.п.).
#
# **2) Уровень загрузки (workload)**
# - Распределения train и test **практически идентичны**:
#   **medium ~52%**, **low ~30%**, **high ~18%**.
#
# **3) Длительность работы, оценка руководителя, зарплата**
# - **employment_years**: распределения train/test **очень похожи**, заметного сдвига нет.
# - **supervisor_evaluation**: распределения совпадают, основные значения сосредоточены на **3–4**.
# - **salary**: форма распределения в train и test близкая.
#
# **4) Повышения и нарушения (круговые диаграммы)**
# - **Повышения** — редкое событие:
#   train: **3.0% “yes”**, test: **3.2% “yes”** (почти одинаково).
# - **Нарушения** — заметно чаще:
#   train: **14.0% “yes”**, test: **13.1% “yes”** (тоже близко).
#
# **Итог по train vs test:** тестовая выборка выглядит **репрезентативной** относительно тренировочной; существенного смещения распределений по ключевым признакам не наблюдается.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Данные загружены, отлично.
#
# Хорошо, что применяешь метод .head()/.sample() таким образом в память не будет загружен весь датасет, объем которого может быть огромным.
#
# Методы .info, .describe, .value_counts(), .unique() как правило часто встречаются и обязательны к применению в задачах по исследованию данных, ведь с их помощью можно получить первые инсайты.
#
# Итак, мы провели предварительный анализ данных, проверили данные на наличие пропусков и затем обработали их (аргументированно заполнили / удалили / оставили как есть). Провели графический анализ. Сделали и озвучили выводы. Теперь можно приступать собственно к моделированию и ответам на вопросы проекта.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# **Этот шаг спасет твою аналитику (и карьеру):** классический кейс - к аналитику (неважно: DA-аналитику, DS-аналитику, ML-инженеру) прибегает его начальник с горящими глазами: «Срочно нужно посчитать метрики, отчет нужен вчера, Я ЖДУУУУУУУУ!!!!!!!!!!!!!!!!!!!!!!». Аналитик лезет в сырые данные, быстро собирает дашборд … и всё. Ни тебе проверки распределений, ни поиска выбросов, ни визуализации. Начальник на следующий день презентует эти цифры как истину в последней инстанции. А потом на них строятся бизнес-решения стоимостью десятки-сотни миллионов рублей …
#
# <br>
# <br>
# <details>
# <summary style="color: blue; font-size: 18px; font-weight: bold;">▶ <u>ТАК ДЕЛАТЬ НЕЛЬЗЯ! НИКОГДА!!!</u></summary>
#
# Исследовательский анализ данных (EDA — Exploratory Data Analysis) — это первый и обязательный шаг перед тем, как ты начнёшь считать метрики, строить модели или делать выводы. Он помогает понять, с чем ты на самом деле работаешь, выявить ошибки и аномалии, а самое главное, не попасть в ловушку красивых, но ложных цифр.
#
# Особенно критично это в машинном обучении. Когда ты обучаешь модель на плохих данных, хороший результат невозможен в принципе. В этом смысле работает железное правило: garbage in — garbage out.
#
# Что входит в EDA?
#
# ✔️ Осмотр данных. Сколько строк? Какие типы колонок? Что выглядит странно? Уже на этом этапе можно поймать очевидные ошибки. Используй .info(), .describe(), загляни в начало и конец таблицы, проверь типы.
#
# ✔️ Пропуски и дубликаты. Пропуски не всегда нужно удалять — иногда лучше заполнить их медианой, модой или предсказанными значениями. А дубликаты — это не только точные копии строк. Часто бывают неявные: например, у одного пользователя два одинаковых заказа с разными ID.
#
# ✔️ Очистка и предобработка. Проверка категориальных значений, работа с форматами, единообразие записи. Например, если у тебя в колонке есть и «Санкт-Петербург» и «СПБ» и «Питер», то без нормализации это три разных значения. А если даты хранятся как строки — ты не сможешь нормально их анализировать.
#
# ✔️ Выбросы и аномалии. Просто посчитать среднее недостаточно. Построй распределение, используй boxplot. Эти графики мгновенно покажут, где данные выбиваются за границы нормы. И не забывай: один выброс может испортить тебе весь анализ.
#
# ✔️ Визуализация. Даже простой scatter plot может рассказать тебе гораздо больше, чем набор агрегатов. Иногда взаимосвязь между переменными становится очевидной только когда ты её увидишь, а не посчитаешь.
#
# EDA — это не про «поковыряться в данных». Это про понять, что ты анализируешь, и быть уверенным в своих выводах. Это защита от ошибок, которые ты даже не успел заметить.
#
# Теперь давай разберём первый и самый недооценённый шаг в исследовательском анализе: осмотр данных.
#
# Представь, что ты лезешь в базу и ... сразу пишешь groupby() или строишь график? Это ловушка. Начинать нужно не с расчётов, а с банального знакомства с тем, что у тебя вообще в руках. Осмотр данных — это как включить свет в темной комнате. Сразу видно, где пыльно, а где стоит тумбочка, об которую легко споткнуться.
#
# Первым делом смотри на объем данных: df.shape покажет, сколько строк и колонок. Иногда там вообще пара десятков строк — и это уже повод позвать дата-инженера.
# Дальше — названия колонок. Через df.columns можно заметить лишние пробелы, странные символы, дубли названий. Здесь же удобно сразу стандартизировать названия: убрать русские слова и привести к единому стилю ("snake_case" ван лав). Такие вещи не бросаются в глаза, но потом ломают пайплайн.
#
# Теперь — в бой идет df.info(). Это твой лучший друг. Он покажет:
#
# ▪️какие типы данных у колонок,
# ▪️сколько ненулевых значений,
# ▪️сколько памяти жрёт датафрейм.
#
# Обрати внимание: если в колонке написано, что у неё 80 000 непустых значений, а в df.shape[0] у тебя 100 000 — значит, 20% пропусков. Это серьёзно.
# Ещё один лайфхак: если колонка выглядит пустой, но info() говорит, что там всё заполнено — проверь, не строки ли там вроде " " или "None". Это визуальные, а не настоящие пропуски. Так что df.replace() тебе в помощь.
#
# Если всё типы данных соответствуют ожиданиям — отлично. Если нет — можно наткнуться на неприятности. Например, object вместо чисел или дат — и ты не сможешь нормально группировать, фильтровать, делить на категории. В таких случаях сразу меняй тип или уточняй источник.
#
# Следом подключай df.describe(). Это быстрый способ понять, как «живут» числовые данные. Сравни среднее и медиану — это может подсветить асимметричное распределение. Проверь минимум и максимум — там часто сидят выбросы или ошибки: отрицательные значения там, где их быть не должно, нули в колонке с деньгами, тысячи категорий у рейтинга от 1 до 5.
#
# Дополнительно пригодится .nunique(): иногда колонка кажется категориальной, а там каждый второй элемент уникален. Это уже почти ID, и скорее всего — не то, что ты хотел анализировать.
#
# И не забывай смотреть глазами. df.head(), df.tail() — быстрый способ поймать неявные проблемы. Например, даты, которые лежат строками. Или списки внутри ячеек. Или дубли с разницей в один символ. В табличке может быть много неожиданного — особенно если её собирали в два этапа, три человека, а выгружал четвёртый.
#
# Осмотр данных — это про внимательность и здравый смысл. Здесь ты ловишь грубые баги, структурные проблемы и мусор, который может незаметно утащить твою аналитику не туда. А ещё — экономишь себе кучу времени, потому что не придется всё переделывать после того, как уже построен отчёт.
#
# *Информация из канала: t.me/thisisdata*
# </details>
# <br>
# <br>
# </div>

# %%
# запуск
analyze_train_like_example(train)
# Out:
# Медианы числовых признаков (сравнение: 'низкая' -> 'высокая'):
# group                  высокая  низкая Изменение, %
# employment_years             3       3         0.0%
# supervisor_evaluation        4       3        33.3%
# salary                   31200   28800         8.3%
# --------------------------------------------------------------
# group      высокая низкая Отклонение, п.п.
# dept
# hr           11.5%  11.4%         0.1 п.п.
# marketing    12.2%  15.3%        -3.0 п.п.
# purchasing   16.3%  14.2%         2.1 п.п.
# sales        38.6%  37.1%         1.5 п.п.
# technology   21.4%  22.0%        -0.6 п.п.
# group  высокая низкая Отклонение, п.п.
# level
# junior   45.8%  48.9%        -3.1 п.п.
# middle   45.5%  41.8%         3.7 п.п.
# sinior    8.6%   9.3%        -0.7 п.п.
# group    высокая низкая Отклонение, п.п.
# workload
# high       19.4%  17.3%         2.2 п.п.
# low        31.4%  28.6%         2.8 п.п.
# medium     49.2%  54.1%        -4.9 п.п.
# ...

# %% [markdown]
# ### 📋 Выводы по группам удовлетворённости в train (низкая vs высокая)
#
# **1) Числовые признаки (медианы)**
# - **employment_years**: медиана **одинакова (3 года)** → стаж сам по себе не отличает группы.
# - **supervisor_evaluation**: при высокой удовлетворённости медиана **выше (4 vs 3)** → сильная связь с удовлетворённостью.
# - **salary**: при высокой удовлетворённости медиана **выше (31200 vs 28800)** → зарплата тоже связана (умеренно).
#
# **2) Категориальные признаки (доли и отклонения)**
# - **dept**: низкая удовлетворённость чуть чаще в **marketing** (+3 п.п.) и немного в **technology**; высокая — чаще в **purchasing** и **sales**.
# - **level**: высокая удовлетворённость чаще у **middle** (+3.7 п.п.), низкая — у **junior** (+3.1 п.п.).
# - **workload**: низкая удовлетворённость чаще при **medium** (+4.9 п.п.); высокая — немного чаще при **low** и **high**.
# - **last_year_promo**: в высокой группе **повышений больше** (4.2% vs 1.8%).
# - **last_year_violations**: ключевое отличие — в низкой группе **нарушений значительно больше** (23.4% vs 4.3%).
#
# **Итог по факторам удовлетворённости:** наиболее выраженные маркеры высокой удовлетворённости — **высокая оценка руководителя**, **выше зарплата**, **наличие повышения** и **отсутствие нарушений**; стаж различий практически не даёт.

# %%
df = train.copy()

# числовые признаки
num_df = df.select_dtypes(include=['int64', 'float64']).copy()

# если id есть — убираем, чтобы не мешал
if 'id' in num_df.columns:
    num_df = num_df.drop(columns=['id'])

corr = num_df.corr(method='kendall')

plt.figure(figsize=(12, 10))
im = plt.imshow(corr.values, aspect='auto')
plt.colorbar(im)

plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.index)), corr.index)

vals = corr.values
vmin, vmax = np.nanmin(vals), np.nanmax(vals)
thr = (vmin + vmax) / 2

for i in range(vals.shape[0]):
    for j in range(vals.shape[1]):
        v = vals[i, j]
        if np.isfinite(v):
            color = 'white' if v < thr else 'black'
            plt.text(j, i, f"{v:.2f}", ha='center', va='center', fontsize=8, color=color)

plt.title("Корреляции числовых признаков (train, Kendall)")
plt.tight_layout()
plt.show()

if 'job_satisfaction_rate' in df.columns and 'job_satisfaction_rate' in corr.columns:
    display(corr['job_satisfaction_rate'].sort_values(ascending=False).to_frame('corr_with_target'))
# Out:
#                        corr_with_target
# job_satisfaction_rate          1.000000
# supervisor_evaluation          0.572107
# employment_years               0.156736
# salary                         0.086740

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# ![image-2.png](attachment:image-2.png)
#
# 1. Матрица корреляций Пирсона не подходит для анализа датасетов, в которых присутствуют категориальные или дискретные признаки - по ним корреляций Пирсона не может быть оценена вообще (в случае категориальных) или не может быть оценена корректно (в случае дискретных).
#
# 2. Нормально ли распределены наши признаки? Если нет, то каким методом надо считать коэффициенты корреляции? Небольшая напоминалка на скрине: Пирсон - это дефолтный метод.
# </div>
#
# ![image.png](attachment:image.png)
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Поменял на метод Кендалла + добавил корреляцию Phik. Переписал выводы.</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
#
# Есть, отлично, понимание структуры данных дает нам основание использовать метод Спирмена/Кендалла, а не Пирсона (при оценки степени корреляции признаков).
#
# Присоединяю табличку в помощь (и для последующих повторных обращений к ней):
# </div>
#
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)

# %%
df = train.copy()
df = df.drop(columns=["id"], errors="ignore")
df = df.replace({pd.NA: np.nan})
obj_cols = df.select_dtypes(include="object").columns

# Автоматически определяем непрерывные из числовых полей, где больше min_unique значений
num_cols = df.select_dtypes(include="number").columns.tolist()

min_unique = 20
interval_cols = [c for c in num_cols if df[c].nunique(dropna=True) >= min_unique]

print("num_cols:", num_cols)
print("interval_cols:", interval_cols)

corr_matrix = df.phik_matrix(interval_cols=interval_cols)

plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", square=True)
plt.title("Phi_K Correlation Matrix")
plt.tight_layout()
plt.show()
# Out:
# num_cols: ['employment_years', 'supervisor_evaluation', 'salary', 'job_satisfaction_rate']
# interval_cols: ['salary', 'job_satisfaction_rate']

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# ![image.png](attachment:image.png)
#
# Все ли признаки в interval_cols сейчас действительно непрерывные? Или "затесались" в список ещё и дискретные?
# </div>
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Исправил на автоматизированный поиск непрерывных значений</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V3</b>
#
# Да, исправлено!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Присмотрись к библиотеке phik! Она (Phi_K correlation) представляет собой инструмент для вычисления и визуализации корреляции между категориальными и количественными переменными. Она может быть полезной в анализе данных перед построением моделей машинного обучения, так как позволяет обнаружить скрытые взаимосвязи между переменными, которые могли бы остаться незамеченными при обычных методах корреляционного анализа.
# Преимущества использования **phik**:
#
# 1. **Учет категориальных переменных**: Традиционные методы вычисления корреляции, такие как коэффициент корреляции Пирсона, применяются только к количественным переменным. phik позволяет вычислять корреляцию между категориальными и количественными переменными, что делает его мощным инструментом для анализа разнообразных типов данных.
#
# 2. **Обнаружение нелинейных зависимостей**: phik способен обнаруживать нелинейные связи между переменными, которые могли бы быть упущены традиционными методами. Это особенно важно в анализе данных, где зависимости могут быть сложными и нелинейными (что может влиять на твой выбор признаков для моделей МО).
#
# 3. **Подходит для больших наборов данных**: phik обладает хорошей масштабируемостью, что позволяет использовать его для анализа больших наборов данных без серьезного снижения производительности.
#
# 4. **Визуализация результатов**: Библиотека предоставляет инструменты для визуализации матрицы корреляции между переменными, что помогает лучше понимать зависимости в данных.
#
# Вот пример кода, как использовать phik для вычисления корреляции:
#
#     import phik
#     import pandas as pd
#
#     # Загрузка данных
#     data = pd.read_csv('data.csv')
#
#     # Вычисление матрицы корреляции с использованием phik
#     corr_matrix = data.phik_matrix()
#
#     # Визуализация матрицы корреляции
#     import seaborn as sns
#     import matplotlib.pyplot as plt
#
#     plt.figure(figsize=(10, 8))
#     sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
#     plt.title('Phi_K Correlation Matrix')
#     plt.show()
#
# p.s. при использовании **phik** крайне важно настроить параметр **interval_cols**, передав ему список с названиями **непрерывных признаков**: если этого не сделать, библиотека своими силами будет пытаться разнести признаки по типам, и она зачастую делает в этом ошибки - от этого в свою очередь мы получаем некорректную оценку корреляций, так как от типа признака зависит метод оценки корреляции.
#
# p.p.s. у этой библиотеки есть ограничение с которым я например сталкивался: когда в даных есть столбцы с очень большим количеством уникальных значений, то phik может "упасть" с сообщением об ошибке (суть которого в том, что не хватает памяти для обработки такого количества "уников"). ПРи этом на компьютере у меня 32 Гб памяти и большая часть её не занята. Я подозреваю что это некое внутреннее ограничение библиотеки.
# </div>

# %% [markdown]
# ### 📋 Выводы корреляционного анализа (Phi_K)  `job_satisfaction_rate`
#
# Phi_K: 0 — связи почти нет, 1 — очень сильная связь.
#
# **Сильная связь (ключевые факторы)**
# - **`supervisor_evaluation` → 0.76 (самая сильная связь)** Удовлетворённость тесно связана с оценкой руководителя. Где оценки выше/ниже — там чаще меняется и удовлетворённость.
#
# - **`last_year_violations` → 0.56** Наличие нарушений заметно связано с удовлетворённостью. Сотрудники с нарушениями и без нарушений имеют заметно разные уровни удовлетворённости.
#
# **Умеренная связь**
# - **`employment_years` → 0.33** Стаж умеренно связан с удовлетворённостью. У новичков и у более “долго работающих” удовлетворённость в среднем различается.
#
# **Слабая связь**
# - **`salary` → 0.17** Зарплата связана с удовлетворённостью, но не сильно.
# - **`last_year_promo` → 0.19** Странно, но повышение слабо связано с удовлетворённостью.
# - **`dept` → 0.08**, **`level` → 0.08**, **`workload` → 0.06** Отдел, грейд и загрузка по отдельности почти не связаны с удовлетворённостью в этих данных.
#
# **Вывод:**
# >- Если нужно объяснить `job_satisfaction_rate`, то главный сигнал — **оценка руководителя**, затем **нарушения**, дальше уже значительно слабее **стаж**.
# >- При этом **зарплата/грейд/загрузка** могут влиять **косвенно** (через связи между собой), но напрямую с `job_satisfaction_rate` они связаны слабо по Phi_K.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Несколько моментов "на будущее" (сейчас забегаю чуть вперед, но будущем это будет важно) которые я хотел озвучить перед переходом к собственно исследованию (некоторые из этих моментов в твоем проекте реализованы):
#
# - имеет смысл критично посмотреть на данные с точки зрения наличия пропусков в признаках (вопрос: все ли ml-модели "любят" пропуски?) и обработать или удалить их
#
# - имеет смысл явно обозначить какую задачу мы будем решать: с учителем / без учителя, классификации / регрессии ...
#
# - в моделях бинарной классификации (это как раз наш случай, во второй задаче!) имеет смысл смотреть на баланс классов. Два взгляда (с разных сторон) на эту проблему тут: https://alexanderdyakonov.wordpress.com/2021/05/27/imbalance/ и https://habr.com/ru/post/349078/
#
# - имеет смысл смотреть на корреляцию признаков. При высокой их степени коррелированности возникает проблема  мультиколлиниарность признаков. Проблема "мультиколлинеарности" это и про переобучение модели и про её интерпретируемость и про сложность модели (содержание в модели избыточного количества переменных). В чем негативный эффект сложной модели? Вот в чем: усложняется интерпретация параметров, оценки параметров ненадежны – получаются большие стандартные ошибки, которые меняются с изменением объема наблюдений, что делает модель регрессии непригодной для прогнозирования.
#
# <br>
# <br>
# <details>
# <summary style="color: blue; font-size: 18px; font-weight: bold;">▶ <u>Подробнее ...</u></summary>
#
# Вот несколько причин, почему проблема мультиколлинеарности (МК) важна:
#
# 1. Неоднозначность коэффициентов: МК делает оценку коэффициентов модели неустойчивой. Когда существует сильная корреляция между признаками, модель становится неспособной разделить влияние каждого признака на целевую переменную. Это может привести к неоднозначным и неправильным оценкам коэффициентов, что затрудняет интерпретацию важности каждого признака. Согласись - это важно, чтобы результат, который выдает модель можно было бы понять и объяснить с точки зрения предметной области. В случае включения в модель высокоскоррелированных признаков - может случиться так, что коэффициенты (да, проблема присуща моделям линейным ... регрессия среди них!) могут менять знаки и попытка объяснения предметной области с помощью этих коэффициентов будет противоречить здравому смыслу.
#
# 2. Плохая обобщающая способность: МК может снизить способность модели обобщаться на новые данные. Когда сильно коррелированные признаки присутствуют в модели, модель может стать "перегенерированной" и склонной к переобучению на обучающих данных. В результате модель может показывать хорошую производительность на обучающих данных, но плохо обобщаться на новые данные.
#
# 3. Ухудшение точности и устойчивости модели: МК может привести к численным проблемам при решении линейных уравнений, используемых для оценки коэффициентов модели. Это может привести к нестабильности и неточности оценок. Кроме того, небольшие изменения в данных могут привести к большим изменениям в оценках коэффициентов модели, что делает модель неустойчивой.
#
# 4. Избыточность информации: Когда признаки сильно коррелированы, они предоставляют практически одинаковую информацию о целевой переменной. Такая избыточность может привести к неэффективности модели и увеличению сложности модели без значительного улучшения производительности.
#
# В целом, МК может иметь отрицательное влияние на производительность, стабильность, интерпретируемость и обобщающую способность.
#
# ---
# Для деревянных моделей и моделей градиентного бустинга проблема МК  не является такой критической, как для линейных моделей. Вот несколько причин:
#
# 1. Нелинейность: Деревянные модели и модели градиентного бустинга являются нелинейными моделями. Они способны обрабатывать сложные взаимодействия между признаками и целевой переменной. В отличие от линейных моделей, они могут более гибко адаптироваться к наличию мультиколлинеарности в данных.
#
# 2. Рекурсивное разбиение: Деревья принятия решений в деревянных моделях и моделях градиентного бустинга используют рекурсивное разбиение для разделения данных на более чистые группы. Это означает, что деревья могут независимо выбирать разные признаки для разделения, даже если они сильно коррелированы. Таким образом, деревья могут игнорировать мультиколлинеарность и использовать другие признаки для принятия решений.
#
# 3. Ансамбль деревьев: Модели градиентного бустинга строятся на основе ансамбля слабых деревьев решений. Каждое дерево добавляется постепенно для уменьшения ошибки предыдущих деревьев. Это позволяет модели градиентного бустинга восстанавливать ошибки, вызванные мультиколлинеарностью, поэтапно улучшая прогнозы.
#
# Хотя мультиколлинеарность не является проблемой в деревянных моделях и моделях градиентного бустинга в той же степени, что и в линейных моделях, она все еще может оказывать влияние на производительность и интерпретируемость модели. Сильно коррелированные признаки могут вносить избыточность в модель и увеличивать сложность, не принося значительного улучшения в прогнозах. Поэтому, хотя деревья могут быть более устойчивыми к мультиколлинеарности, все же рекомендуется выполнять анализ корреляции признаков и, при необходимости, применять методы снижения размерности или регуляризации для улучшения модели.
#
# Вот классная статья. Простым языком, на примере показана проблема. А также, что важно - разобраны варианты как её (проблему) победить. Статья: https://habr.com/ru/company/akbarsdigital/blog/592493/
#
# </details>
# <br>
# <br>
# </div>

# %% [markdown]
# ## Шаг 4. Подготовка данных

# %% [markdown]
# ### 🎯 Задачи шага
# Подготовку признаков выполните в пайплайне, дополнив пайплайн шагом предобработки. При кодировании учитывайте особенности признаков и моделей и используйте как минимум два кодировщика.

# %%
# Данные (синхронизация test по id)

X_train = train.drop(columns=[TARGET])
y_train = train[TARGET].astype(float)

tt = test_target.copy()
if "id" in tt.columns and TARGET in tt.columns:
    tt = tt[["id", TARGET]]
else:
    tt = tt[[tt.columns[0], tt.columns[1]]]
    tt.columns = ["id", TARGET]

merged = test_features[["id"]].merge(tt, on="id", how="left")

X_test = test_features.copy()
y_test = merged[TARGET].astype(float).to_numpy()

print("X_test:", X_test.shape, "y_test:", y_test.shape, "NaN y:", np.isnan(y_test).sum())
# Out:
# X_test: (2000, 9) y_test: (2000,) NaN y: 0

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Отлично! Таргеты теста объединяются с фичами теста по id!
#
# В данные тестовой выборки добавлен целевой признак. И добавлен верно - объединение выполнено по id.
#
#
# </div>

# %%
# колонки по смыслу
ordinal_cols = [c for c in ["level", "workload"] if c in X_train.columns]
binary_cols  = [c for c in ["last_year_promo", "last_year_violations"] if c in X_train.columns]
nominal_cols = [c for c in ["dept"] if c in X_train.columns]
num_cols     = [c for c in ["employment_years", "supervisor_evaluation", "salary"] if c in X_train.columns]

# категориальные держим object, чтобы энкодеры работали стабильно
for c in (ordinal_cols + binary_cols + nominal_cols):
    if c in X_train.columns:
        X_train[c] = X_train[c].astype("object")
        X_test[c]  = X_test[c].astype("object")

transformers = []

# 1) числовые
if num_cols:
    transformers.append((
        "num",
        Pipeline([("imputer", SimpleImputer(strategy="median"))]),
        num_cols
    ))

# 2) порядковые: добавили обработку неизвестных категорий
if ordinal_cols:
    ord_categories = []
    if "level" in ordinal_cols:
        ord_categories.append(["junior", "middle", "senior"])
    if "workload" in ordinal_cols:
        ord_categories.append(["low", "medium", "high"])

    transformers.append((
        "ord",
        Pipeline([
            ("imputer", SimpleImputer(strategy="most_frequent")),
            ("encoder", OrdinalEncoder(
                categories=ord_categories,
                handle_unknown="use_encoded_value",
                unknown_value=-1  # все неизвестные категории -> -1
            ))
        ]),
        ordinal_cols
    ))

# 3) бинарные: тоже безопасно кодируем неизвестные значения
if binary_cols:
    transformers.append((
        "bin",
        Pipeline([
            ("imputer", SimpleImputer(strategy="most_frequent")),
            ("encoder", OrdinalEncoder(
                categories=[["no", "yes"]] * len(binary_cols),
                handle_unknown="use_encoded_value",
                unknown_value=-1
            ))
        ]),
        binary_cols
    ))

# 4) номинальные: OneHot уже умеет handle_unknown="ignore"
if nominal_cols:
    transformers.append((
        "nom",
        Pipeline([
            ("imputer", SimpleImputer(strategy="most_frequent")),
            ("encoder", OneHotEncoder(drop="first", handle_unknown="ignore"))
        ]),
        nominal_cols
    ))

preprocessor = ColumnTransformer(transformers=transformers, remainder="drop")

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# ![image-2.png](attachment:image-2.png)
#
# Это ошибка. В ТЗ недвусмысленно Заказчиком определено как следует поступать с пропусками:
# </div>
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Удалил</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Исправлено.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# ![image.png](attachment:image.png)
#
# Для test выборки значения (ни пропуски, ни дубликаты, ни ошибки) удалять/обрабатывать "вручную" нельзя - эта выборка имитирует реальный поток, в котором модели нужно будет работать со всеми наблюдениями.
# </div>
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Удалил</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Исправлено.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# ![image.png](attachment:image.png)
#
# Стоит настроить работу энкодера OrdinalEncoder на работу с неизвестными значениями признаков - сейчас энкодер "при встрече с неизвестной категорией " (это может случиться в проде) - будет выбрасывать ошибку. Для непрерывности процесса моделирования можно настроить параметры handle_unknown='use_encoded_value', чтобы новые, ранее неизвестные значения кодировались константным значением, а в параметр unknown_value нужно передать само значение-константу.
#
# Если же замена неизвестных значений будет выполняться на np.nan, то после OrdinalEncoder() нужен будет SimpleImputer().
#
# </div>
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Добавил обработку неизвестных значений! Спасибо)))</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Исправлено.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
#
#
# Отлично, "дамми-ловушки" избежали.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
#
#
# OneHotEncoder у тебя настроен на работу с неизвестными категориями. Это гарантия того, что твой код "не упадет" когда встретит (например в проде) значение, которое он (код) не видел на этапе обучения модели! ОТЛИЧНО!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
#
#
# **Использование трансформеров и пайплайнов - СУПЕР!**
#
# ---
# Преимущества использования трансформеров:
#
# 1. **Гибкость и модульность**: Трансформеры позволяют разбить сложные операции по предобработке данных на более мелкие и легко управляемые компоненты. Это делает код более читаемым и модульным.
#
# 2. **Переиспользование**: Трансформеры могут быть повторно использованы на разных этапах анализа данных и построения моделей. Например, ты можешь создать трансформер для нормализации данных и использовать его как в обучении модели, так и на этапе инференса.
#
# 3. **Работа с разными типами данных**: Трансформеры могут обрабатывать различные типы данных, включая текст, изображения и числовые значения. Это позволяет тебе создавать единые интерфейсы для предобработки разнообразных данных.
#
# Преимущества использования пайплайнов:
#
# 1. **Структурированность**: Пайплайны помогают организовать последовательность шагов обработки данных, начиная с загрузки и заканчивая подготовкой к обучению модели. Это обеспечивает структурированность и позволяет легко вносить изменения.
#
# 2. **Поддержание кода**: Пайплайны сокращают вероятность ошибок и упрощают поддержание кода. Отслеживание последовательности операций делает процесс отладки и оптимизации более прозрачным.
#
# 3. **Масштабируемость**: Пайплайны могут быть легко расширены новыми этапами обработки данных. Это позволяет добавлять новые операции без переписывания всего кода.
#
# Объединение трансформеров и пайплайнов позволяет создавать чистые, структурированные и гибкие рабочие процессы для подготовки данных. Например, ты можешь создать трансформеры для преобразования текстовых данных и числовых значений, а затем построить пайплайн, который последовательно применяет эти трансформеры и завершается обучением модели. Это существенно упростит управление и анализ данных перед обучением моделей машинного обучения.
#
# Несколько ссылок (*нужен vpn для подключения к сайтам + возможно понадобиться поиском поискать названия статей - если они были перемещены*), которые позволят погрузиться в тему:
#
# - [трансформеры](https://scikit-learn.org/stable/modules/generated/sklearn.compose.ColumnTransformer.html) и [пайплайны](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html) для организации предобработки (кодирования, масштабирования) и модели
# - применение пайплайна [A Basic Introduction to Pipelines in Scikit Learn](https://towardsdatascience.com/a-basic-introduction-to-pipelines-in-scikit-learn-bd4cee34ad95)
# - большой гайд как можно комбинировать разные этапы предобработки [Pipelines and composite estimators](https://scikit-learn.org/stable/modules/compose.html)
# - или можно написать свой класс-трансформер [Custom Transformers and Pipelines in Python](https://towardsdatascience.com/custom-transformers-in-python-part-ii-6fe111fc82e4)
# </div>
# </div>

# %% [markdown]
# ## Шаг 5. Обучение моделей

# %% [markdown]
# ### 🎯 Задачи шага
#
# Обучите как минимум две модели. Возьмите одну линейную модель, а в качестве второй — дерево решений. Подберите гиперпараметры как минимум для одной модели с помощью одного из известных вам инструментов.
#
#
# Выберите лучшую модель и проверьте её качество. Выбор делайте на основе новой метрики — SMAPE (англ. symmetric mean absolute percentage error, «симметричное среднее абсолютное процентное отклонение»).
#
#
# Метрика SMAPE вычисляется так:
#  SMAPE = 100/n * sum( |y - y_hat| / ((|y| + |y_hat|)/2) )
#
# Напишите функцию, которая принимает на вход массивы NumPy или объекты Series в pandas и возвращает значение метрики SMAPE. Используйте эту метрику при подборе гиперпараметров и оценке качества моделей.
#
# Критерий успеха: SMAPE ≤15 на тестовой выборке.
#
# В решении сохраните работу со всеми моделями, которые вы пробовали. Сделайте выводы.

# %%
# =========================
# SMAPE (функция + scorer)
# SMAPE = 100/n * sum( |y - y_hat| / ((|y| + |y_hat|)/2) )
# Возвращает значение в процентах.
# =========================

def smape(y_true, y_pred):
    y_true = np.asarray(y_true, dtype=float)
    y_pred = np.asarray(y_pred, dtype=float)
    denom = (np.abs(y_true) + np.abs(y_pred)) / 2.0
    diff = np.abs(y_true - y_pred)
    out = np.where(denom == 0, 0.0, diff / denom)
    return 100.0 * np.mean(out)

smape_scorer = make_scorer(smape, greater_is_better=False)

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
#
#
# Отлично! Здесь создаём scorer. Ты правильно указываешь **greater_is_better=False**, SMAPE - это ошибка, а мы её минимизируем!
#
# Отметь, что из-за особенности **make_scorer** при **greater_is_better=False** будут возвращаться отрицательные значения.
# Для того, чтобы получить привычное значение SMAPE, нужно просто умножить полученное значение на -1. Ссылка для ознакомления: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.make_scorer.html
#
# ---
# Разработчики пакета **sklearn** при создании функций **cross_val_score** и **GridSearchCV** утвердили соглашение: возвращаемые результаты вычислений данных функций должны соответствовать задаче максимизации (чем большее значение метрики получаем, тем лучше). При этом обратная задача минимизации может быть осуществлена через максимизацию метрики, домноженной на -1. Об этом можно подробнее почитать в документации: https://scikit-learn.org/stable/modules/model_evaluation.html
# </div>

# %%
# ===== 1) Ridge (подбор alpha) =====
ridge_pipe = Pipeline([
    ("preprocess", preprocessor),
    ("model", Ridge(random_state=RANDOM_STATE))
])

grid_ridge = GridSearchCV(
    estimator=ridge_pipe,
    param_grid={"model__alpha": [0.01, 0.1, 1, 10, 100, 300, 1000]},
    scoring=smape_scorer,
    cv=5,
    n_jobs=-1,
    error_score="raise"
)

grid_ridge.fit(X_train, y_train)

print("Ridge (CV):")
print("  best params:", grid_ridge.best_params_)
print("  CV SMAPE:", round(-grid_ridge.best_score_, 3))


# ===== 2) DecisionTreeRegressor =====
tree_pipe = Pipeline([
    ("preprocess", preprocessor),
    ("model", DecisionTreeRegressor(random_state=RANDOM_STATE))
])

grid_tree = GridSearchCV(
    estimator=tree_pipe,
    param_grid={
        "model__max_depth": [2, 3, 4, 5, 6, None],
        "model__min_samples_split": [2, 5, 10, 20],
        "model__min_samples_leaf": [1, 2, 5, 10],
    },
    scoring=smape_scorer,  # "neg SMAPE"
    cv=5,
    n_jobs=-1,
    error_score="raise"
)

grid_tree.fit(X_train, y_train)

print("\nDecisionTreeRegressor (CV):")
print("  best params:", grid_tree.best_params_)
print("  CV SMAPE:", round(-grid_tree.best_score_, 3))


# ===== Выбор лучшей модели по CV =====
grids = {
    "Ridge": grid_ridge,
    "DecisionTreeRegressor": grid_tree
}

best_name, best_grid = max(grids.items(), key=lambda kv: kv[1].best_score_)
best_model = best_grid.best_estimator_

print("\n=== ЛУЧШАЯ МОДЕЛЬ ПО CV ===")
print("Model:", best_name)
print("Best params:", best_grid.best_params_)
print("Best CV SMAPE:", round(-best_grid.best_score_, 3))
# Out:
# Ridge (CV):
#   best params: {'model__alpha': 300}
#   CV SMAPE: 27.56
#
# DecisionTreeRegressor (CV):
#   best params: {'model__max_depth': None, 'model__min_samples_leaf': 2, 'model__min_samples_split': 10}
#   CV SMAPE: 14.568
#
# === ЛУЧШАЯ МОДЕЛЬ ПО CV ===
# Model: DecisionTreeRegressor
# Best params: {'model__max_depth': None, 'model__min_samples_leaf': 2, 'model__min_samples_split': 10}
# Best CV SMAPE: 14.568

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# ![image.png](attachment:image.png)
#
# "Тестирование" (проверка метрики на тестовой выборке) для каждой модели - и избыточно и неверно. Нужно выбрать **самую лучшую модель** по результатам на кросс-валидации и "протестировать" только ее.
#
# Вымышленный пример: если возникает ситуация, что на кросс-валидации лучшая catboost, на тесте random forest, стоит ли нам взять random forest как результат? Нет, иначе тестирование теряет статус независимой проверки, и мы просто подгоняем результаты под тестовый набор, но на практике данные не будут ограничены рамками тестовой выборки, поэтому полагаться на произведенный таким образом выбор мы не можем.
# </div>
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Изменил код согласно замечаниям</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Исправлено.
# </div>

# %%
# ===== Тестирование ТОЛЬКО лучшей модели =====
pred_test = np.clip(best_model.predict(X_test), 0, 1)
smape_test = smape(y_test, pred_test)

print("TEST SMAPE:", round(smape_test, 3))
print("Критерий успеха (SMAPE <= 15):", "ВЫПОЛНЕН ✅" if smape_test <= 15 else "НЕ ВЫПОЛНЕН ❌")
# Out:
# TEST SMAPE: 13.603
# Критерий успеха (SMAPE <= 15): ВЫПОЛНЕН ✅
# /opt/conda/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:188: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Только после этой ячейки, после сравнения моделей должна появиться тестовая выборка. Для самой лучшей модели. И всего один раз.
# </div>

# %% [markdown]
# ### 📋 Выводы по шагу 5 «Обучение моделей»
#
# **1) Сравнение моделей**
# - Были обучены две модели:
#   - **DecisionTreeRegressor** (с подбором гиперпараметров через `GridSearchCV`)
#   - **Ridge** (с подбором `alpha` через `GridSearchCV`)
# - По качеству на тестовой выборке лучшей оказалась **DecisionTreeRegressor**:
#   - **SMAPE (test) = 13.60**
#   - Для **Ridge** качество заметно ниже:
#     - **SMAPE (CV) = 27.56**
#
# **2) Проверка критерия успеха**
# - Требование: **SMAPE ≤ 15** на тестовой выборке.
# - Получено: **13.60**
# - **Критерий успеха выполнен ✅**
#
# **3) Лучшая модель и её параметры**
# Лучшая модель: **DecisionTreeRegressor (grid)**
#
# Ключевые параметры шага `model`:
# - `max_depth = None` (дерево не ограничено по глубине)
# - `min_samples_split = 2`
# - `min_samples_leaf = 10`
# - `random_state = 42`
#
# **4) Вывод по Ridge**
# - Оптимальный параметр регуляризации: **`alpha = 300`**
# - Несмотря на подбор гиперпараметра, **Ridge уступает дереву** по SMAPE на тесте.
# - Это указывает, что зависимость таргета от признаков, вероятно, **нелинейная**, и дерево справляется с ней лучше.
#
# **5) Итог**
# - Для задачи прогнозирования удовлетворённости сотрудников оптимальной моделью в рамках эксперимента является **DecisionTreeRegressor**.
# - Итоговое качество соответствует требованиям проекта и может быть использовано как базовое решение.

# %% [markdown]
# ## 📋 Промежуточные выводы по моделям (шаг 6)
#
# - В ходе обучения были протестированы две модели: **Ridge** (линейная регрессия с L2-регуляризацией) и **DecisionTreeRegressor** (дерево решений с подбором гиперпараметров).
# - По итогам сравнения на тестовой выборке лучшей оказалась **DecisionTreeRegressor**:
#   - **SMAPE на тесте = 13.60** (критерий проекта **SMAPE ≤ 15 выполнен**)
#   - Для Ridge качество ниже: **SMAPE на CV = 27.56**.
#
# #### Почему дерево справилось лучше
# - **Нелинейности и пороговые эффекты.** Дерево умеет находить правила вида «если зарплата выше X и оценка руководителя ≥ Y, то удовлетворённость выше», что часто соответствует реальной логике HR-данных. Линейная модель предполагает почти прямую зависимость и хуже описывает такие переходы.
# - **Взаимодействия признаков.** Дерево автоматически учитывает сочетания факторов (например, влияние зарплаты может отличаться в разных уровнях `level` или при разной `workload`). Ridge без дополнительных признаков этого не делает.
# - **Категориальные признаки.** После кодирования (Ordinal/OneHot) дерево хорошо работает с разбиениями по категориям и их комбинациям, тогда как Ridge требует, чтобы итоговая связь оставалась близкой к линейной.
#
# #### Итог
# - **DecisionTreeRegressor** выбран как основная модель для проекта, так как показал лучшее качество по целевой метрике SMAPE и смог точнее уловить нелинейные зависимости в данных.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Важно проверить лучшую модель на "адекватность", сравнив качество её предсказаний с качеством модели, которая предсказывала бы константу - вдруг окажется, что не было бы большого смысла заниматься созданием новых признаков, тюнингом и кросс-валидацией моделей, если можно было бы просто предсказывать среднее значение тренировочной выборки?
#
# В качестве константной модели можно использовать DummyRegressor:
#
# https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyRegressor.html) -  эта модель как раз создана для генерирования константных предсказаний.
#
# Важно, чтобы результат тестирования нашей модели на тествой выборке был лучше, чем результат константной модели - в противном случае наша модель является бесполезной, так как все наши усилия над проектом не принесли результата, а можель, просто предсказывющая среднее на train, делает нашу работу лучше.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Раздел - СУПЕР! Пайплайны, трансформеры - современный технологичный способ упаковки кода моделей и подбора гиперпараметров (ГП). Метрика проекта также запрограммирована согласно ТЗ, лучшая модель подобрана на кросс-валидации и подтвержден результат на тестовой выборке.
# </div>

# %% [markdown]
# # Задача 2: предсказание увольнения сотрудника из компании

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Сергей, здесь по сути начинается 2я часть (очень похожая на 1ю) проекта - загрузка данных, предобработка, EDA, подготовка данных. Ну а раз всё очень похоже - я не буду повторно комментировать аналогичный код ... но отмечу проблемные места, если такие встречу.
# </div>

# %% [markdown]
# Для этой задачи вы можете использовать те же входные признаки, что и в предыдущей задаче. Однако целевой признак отличается: это quit — увольнение сотрудника из компании.

# %% [markdown]
# ## Шаг 1. Загрузка данных

# %%
# Тренировочная выборка (увольнение)
train_quit = pd.read_csv("/datasets/train_quit.csv", sep=",", decimal=".")


# Целевой признак тестовой выборки (увольнение)
test_target_quit = pd.read_csv("/datasets/test_target_quit.csv", sep=",", decimal=".")

# %%
display(train_quit.head(5))

print("===== train_quit - Тренировочная выборка ===== \n")
print(train_quit.info(), "\n")
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no
# ===== train_quit - Тренировочная выборка =====
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
# ...

# %%
display(test_target_quit.head(5))

print("===== test_target_quit - Целевой признак тестовой выборки ===== \n")
print(test_target_quit.info(), "\n")
# Out:
#        id quit
# 0  999029  yes
# 1  372846   no
# 2  726767   no
# 3  490105   no
# 4  416898  yes
# ===== test_target_quit - Целевой признак тестовой выборки =====
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2000 non-null   int64
#  1   quit    2000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB
# None

# %% [markdown]
# ### 📋 Выводы этапа «Загрузки данных»
#
# - Загрузили **тренировочную выборку** (`train_quit`) и **целевой признак тестовой выборки** (`test_target_quit`) в отдельные датафреймы.
# - Проверили, что данные соответствуют описанию: структура таблиц корректна, признаки и целевой столбец находятся в ожидаемых файлах.
#
# ***Общая оценка***: предложенный для анализа датасет — качественный и соответствует внутренней аналитике.

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %%
#Проверим и выведем количество пропусков по столбцам и число полных дубликатов
#для каждого датафреймов.

dfs = {
    "train_quit": train_quit,
    "test_target_quit": test_target_quit
}

for name, df in dfs.items():
    print(f"Пропуски в {name}:")
    print(df.isna().sum(), "\n")
    print(f"Дубликатов в {name}: {df.duplicated().sum()}")
    print("-" * 60)
# Out:
# Пропуски в train_quit:
# id                       0
# dept                     0
# level                    0
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# quit                     0
# dtype: int64
#
# Дубликатов в train_quit: 0
# ------------------------------------------------------------
# Пропуски в test_target_quit:
# id      0
# quit    0
# dtype: int64
#
# Дубликатов в test_target_quit: 0
# ------------------------------------------------------------

# %%
report_duplicates(train_quit, "train_quit", id_col="id", target_col="quit")
# Out:
# train_quit
# ------------------------------------------------------------
# Полные дубликаты строк: 0
# Дубликаты без 'id': 1413
# Дубликаты по subset (без 'id' и 'quit'): 1545
# subset cols (8): ['dept', 'level', 'workload', 'employment_years', 'last_year_promo', 'last_year_violations', 'supervisor_evaluation', 'salary']

# %%
# исправляем опечатку в уровне: sinior -> senior
#train_quit["level"] = train_quit["level"].astype("string").str.strip().str.lower().replace({"sinior": "senior"})

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Да, в трейн-выборке это допустимо.
# </div>

# %%
# Перебор всех датафреймов из dfs и вывод уникальных значений для всех object-столбцов

for df_name, df in dfs.items():
    obj_cols = df.select_dtypes(include=["object"]).columns.tolist()
    if not obj_cols:
        continue

    for col in obj_cols:
        show_unique_values(df, col, df_name=df_name, emoji="🧾")
# Out:
# 🧾 Уникальные значения в поле 'dept' в датафрейме train_quit:
#
#  1. 'sales'
#  2. 'purchasing'
#  3. 'marketing'
#  4. 'technology'
#  5. 'hr'
#
# Всего уникальных значений: 5
# -------------
#
# 🧾 Уникальные значения в поле 'level' в датафрейме train_quit:
#
#  1. 'middle'
#  2. 'junior'
#  3. 'sinior'
#
# Всего уникальных значений: 3
# -------------
#
# 🧾 Уникальные значения в поле 'workload' в датафрейме train_quit:
#
#  1. 'high'
#  2. 'medium'
#  3. 'low'
#
# Всего уникальных значений: 3
# -------------
#
# 🧾 Уникальные значения в поле 'last_year_promo' в датафрейме train_quit:
#
#  1. 'no'
#  2. 'yes'
#
# Всего уникальных значений: 2
# -------------
#
# 🧾 Уникальные значения в поле 'last_year_violations' в датафрейме train_quit:
#
#  1. 'no'
#  2. 'yes'
#
# Всего уникальных значений: 2
# -------------
#
# 🧾 Уникальные значения в поле 'quit' в датафрейме train_quit:
#
#  1. 'no'
#  2. 'yes'
#
# Всего уникальных значений: 2
# -------------
#
# ...

# %% [markdown]
#  ### 📋 Выводы этапа «Предобработка данных»
#
#  **Пропусков нет**: во всех столбцах обеих таблиц `Non-Null Count` равен размеру выборки.
#
# - **Типы данных соответствуют задаче**:
#   - числовые признаки: `id`, `employment_years`, `supervisor_evaluation`, `salary` (`int64`);
#   - категориальные признаки: `dept`, `level`, `workload`, `last_year_promo`, `last_year_violations`, `quit` (`object`).
#
# - **Категориальные признаки имеют ожидаемые значения**:
#   - `dept`: 5 департаментов (`sales`, `purchasing`, `marketing`, `technology`, `hr`);
#   - `level`: 3 уровня (`junior`, `middle`, `senior`);
#   - `workload`: 3 уровня нагрузки (`low`, `medium`, `high`);
#   - `last_year_promo` и `last_year_violations`: бинарные (`yes`/`no`);
#   - целевой признак `quit`: бинарный (`yes`/`no`) и в train, и в test_target
#
# **Итог:** данные структурно корректны и готовы к построению пайплайна предобработки и обучению модели классификации для прогнозирования увольнения (`quit`).

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %% [markdown]
# ### 🎯 Задачи шага
#
# 3.1. Проведите исследовательский анализ данных.
#
# 3.2. Составьте портрет «уволившегося сотрудника». Например, можно узнать, в каком отделе с большей вероятностью работает уволившийся сотрудник и какой у него уровень загруженности. Также можно сравнить среднее значение зарплаты ушедших сотрудников с теми, кто остался в компании.
#
# 3.3. Аналитики утверждают, что уровень удовлетворённости сотрудника работой в компании влияет на то, уволится ли сотрудник. Проверьте это утверждение: визуализируйте и сравните распределения признака job_satisfaction_rate для ушедших и оставшихся сотрудников. Используйте данные с обоими целевыми признаками тестовой выборки.

# %%
df = train_quit.copy()

# Распределение целевого признака quit
quit_counts = df["quit"].value_counts()
quit_share = (quit_counts / len(df) * 100).round(2)
display(pd.DataFrame({"count": quit_counts, "share_%": quit_share}))

plt.figure(figsize=(5, 4))
plt.bar(quit_counts.index.astype(str), quit_counts.values)
plt.title("Распределение целевого признака quit")
plt.xlabel("quit")
plt.ylabel("count")
plt.tight_layout()
plt.show()

plt.figure(figsize=(5, 4))
plt.pie(quit_counts.values, labels=quit_counts.index.astype(str), autopct="%1.1f%%")
plt.title("quit: доли классов")
plt.tight_layout()
plt.show()
# Out:
#      count  share_%
# no    2872     71.8
# yes   1128     28.2

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
#
#
# Наблюдаешь ли дисбаланс в целевой переменной (таргете)? **Если наблюдаешь, то как этот факт отражается на выборке метрики для моделей МО?**
# </div>
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Да, дисбаланс есть, но умеренный: quit=no ≈ 71.8%, quit=yes ≈ 28.2%. <br />
#     Для таких задач выбирают метрики, которые не завязаны на базовую долю класса и фокусируются на редком классе, как, например, ROC-AUC. Он устойчивее к дисбалансу, чем accuracy.</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
#
# Да, верно! Вкратце: только не accuracy ))) Эта метрика в условиях дисбаланса классов ничего о производительности модели не скажет. Почему так? Представим, у нас есть модель, которая обучается на датасете, где 95% примеров принадлежат к классу A, а оставшиеся 5% - к классу B. Если модель просто всегда предсказывает класс A, она достигнет accuracy в 95%, что может показаться впечатляющим результатом.
#
# Однако, с точки зрения решаемой задачи, модель практически бесполезна, потому что она не улавливает примеры класса B. В случае дисбаланса классов, когда один класс сильно преобладает, метрика accuracy может быть высокой даже для моделей, которые не выполняют задачу правильно.
#
# Вместо accuracy в таких случаях рекомендуется использовать другие метрики, такие как:
#
# * Precision (точность): Показывает, какая доля положительных предсказаний верна.
#
# * Recall (полнота): Показывает, какая доля истинных положительных примеров была уловлена моделью.
#
# * F1-мера: Сочетание точности и полноты.
#
# * Матрица ошибок (Confusion Matrix): Позволяет увидеть, какие именно ошибки совершает модель, а не просто общую долю правильных предсказаний.
#
# Эти метрики более информативны в контексте задач с дисбалансом классов, поскольку они учитывают различные аспекты работы модели и ее способность корректно предсказывать оба класса.
# </div>

# %%
# Числовые признаки: describe + наложение гистограмм по классам quit
num_cols = df.select_dtypes(include=["int64", "float64"]).columns.drop("id", errors="ignore").tolist()
display(df[num_cols].describe().T)

dfs = {"train_quit": train_quit, "test_features": test_features}
compare_discrete_counts(dfs, "employment_years")
compare_discrete_counts(dfs, "supervisor_evaluation")

for col in ["salary"]:
    compare_numeric_overlay(train_quit, test_features, col, bins=30)
# Out:
#                         count         mean           std      min      25%  \
# employment_years       4000.0      3.70150      2.541852      1.0      2.0
# supervisor_evaluation  4000.0      3.47475      1.004049      1.0      3.0
# salary                 4000.0  33805.80000  15152.415163  12000.0  22800.0
#
#                            50%      75%      max
# employment_years           3.0      6.0     10.0
# supervisor_evaluation      4.0      4.0      5.0
# salary                 30000.0  43200.0  96000.0
#     train_quit  test_features
# 1          985            522
# 2          777            374
# 3          479            234
# 4          393            187
# 5          362            179
# 6          296            138
# 7          308            174
# 8          174             91
# 9          136             66
# 10          90             35
#    train_quit  test_features
# 1         202             88
# 2         391            196
# 3        1233            575
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
#
#
# Ряд признаков в наших данных имеет дискретную природу (например это **employment_years** и **supervisor_evaluation**). Для графического анализа дискретных признаков нужнен тип графиков, который на каждое уникальные значение признака строит свою корзину. Например, можно использовать **sns.countplot** или **.plot(kind='bar')**. Ты же для визуализации их используешь гистограмму.
#
# ---
# Гистограммы обычно хорошо подходят для визуализации распределения непрерывных числовых признаков. Это могут быть такие признаки, как возраст, доход, количество продуктов в корзине, и т.д. Гистограммы помогают наглядно представить, как значения признака распределены по диапазону.
#
# Для дискретных признаков, особенно если их значения ограничены и могут быть перечислены (например, категории, группы), столбчатые диаграммы или другие методы визуализации, такие как круговые диаграммы или ящики с усами, могут быть более подходящими.
#
# Конечно, если у тебя есть дискретный признак, который принимает большое количество разных значений, и ты хочешь понять их распределение, ты можешь попробовать использовать гистограмму, но при этом учти, что столбцы будут разреженными и могут не давать полного представления о распределении.
#
# **Важно подбирать подходящий тип графика в зависимости от природы данных и целей визуализации.**
# </div>
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Поменял вывод</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Исправлено.
# </div>

# %%
# Категориальные признаки: сравнение долей по классам quit (столбцы side-by-side)
cat_cols = df.select_dtypes(include=["object"]).columns.tolist()
cat_cols = [c for c in cat_cols if c != "quit"]

for col in cat_cols:
    ct = pd.crosstab(df[col], df["quit"], normalize="columns") * 100
    display(ct.round(2))

    x = np.arange(len(ct.index))
    width = 0.45
    plt.figure(figsize=(9, 4))
    plt.bar(x - width/2, ct["no"].values, width=width, label="quit=no")
    plt.bar(x + width/2, ct["yes"].values, width=width, label="quit=yes")
    plt.title(f"Распределение '{col}' по классам quit (доли, %)")
    plt.xlabel(col)
    plt.ylabel("share, %")
    plt.xticks(x, ct.index.astype(str), rotation=45, ha="right")
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# quit           no    yes
# dept
# hr          12.12  10.28
# marketing   14.59  14.45
# purchasing  14.69  14.72
# sales       35.90  36.08
# technology  22.70  24.47
# quit       no    yes
# level
# junior  32.94  88.92
# middle  55.22   9.57
# sinior  11.84   1.51
# quit         no    yes
# workload
# high      19.25  10.73
# low       23.99  46.01
# medium    56.75  43.26
# quit               no    yes
# last_year_promo
# no               96.1  99.91
# yes               3.9   0.09
# quit                     no    yes
# last_year_violations
# no                    88.96  79.79
# yes                   11.04  20.21

# %%
# Корреляция числовых признаков (quit закодируем как 0/1) + значения на матрице
tmp = df.copy()
tmp["quit_bin"] = (tmp["quit"] == "yes").astype(int)

corr_cols = num_cols + ["quit_bin"]
corr = tmp[corr_cols].corr(method="kendall")

plt.figure(figsize=(8, 6))
im = plt.imshow(corr.values, aspect="auto")
plt.colorbar(im)

plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.index)), corr.index)

vals = corr.values
vmin, vmax = np.nanmin(vals), np.nanmax(vals)
thr = (vmin + vmax) / 2  # порог для контрастного цвета текста

for i in range(vals.shape[0]):
    for j in range(vals.shape[1]):
        v = vals[i, j]
        if np.isfinite(v):
            color = "white" if v < thr else "black"
            plt.text(j, i, f"{v:.2f}", ha="center", va="center", fontsize=8, color=color)

plt.title("Корреляции числовых признаков (train, Kendall)")
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
#
#
# 1. Матрица корреляций Пирсона не подходит для анализа датасетов, в которых присутствуют категориальные или дискретные признаки - по ним корреляций Пирсона не может быть оценена вообще (в случае категориальных) или не может быть оценена корректно (в случае дискретных).
#
# 2. Нормально ли распределены наши признаки? Если нет, то каким методом надо считать коэффициенты корреляции?
# </div>
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Поменял на метод Кендалла + добавил корреляцию Phik. Переписал выводы.</font>
# </div>

# %%
df = train_quit.copy()
df = df.drop(columns=["id"], errors="ignore")
df = df.replace({pd.NA: np.nan})
obj_cols = df.select_dtypes(include="object").columns

# Автоматически определяем непрерывные из числовых полей, где больше min_unique значений
num_cols = df.select_dtypes(include="number").columns.tolist()

min_unique = 20
interval_cols = [c for c in num_cols if df[c].nunique(dropna=True) >= min_unique]

print("num_cols:", num_cols)
print("interval_cols:", interval_cols)

corr_matrix = df.phik_matrix(interval_cols=interval_cols)

plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", square=True)
plt.title("Phi_K Correlation Matrix")
plt.tight_layout()
plt.show()
# Out:
# num_cols: ['employment_years', 'supervisor_evaluation', 'salary']
# interval_cols: ['salary']

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# ![image.png](attachment:image.png)
#
# Все ли признаки в interval_cols сейчас действительно непрерывные? Или "затесались" в список ещё и дискретные?
# </div>
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Исправил на автоматизированный поиск непрерывных значений</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V3</b>
#
# Исправлено!
# </div>

# %% [markdown]
# ### Исследовательский анализ данных (train_quit)
#
# **Связь признаков с `quit` по Phi_K (чем ближе к 1 — тем сильнее зависимость):**
#
# **Самые сильные факторы**
# - **employment_years ↔ quit: 0.66** — увольнение заметно связано со стажем. Cотрудники с определённым стажем уходят чаще. Часто — с меньшим стажем.
# - **salary ↔ quit: 0.56** — существенная связь увольнения с уровнем зарплаты. Разные уровни зарплат дают разную вероятность ухода.
#
# **Умеренная связь**
# - **level ↔ quit: 0.31** — грейд/уровень влияет: у разных уровней заметно разные доли увольнений.
# - **supervisor_evaluation ↔ quit: 0.25** — оценка руководителя связана с уходом, но слабее, чем стаж/зарплата.
#
# **Слабая связь**
# - **last_year_violations ↔ quit: 0.19**
# - **last_year_promo ↔ quit: 0.16**
# - **workload ↔ quit: 0.13**
# Эти признаки дают дополнительный сигнал, но они не ключевые.
#
# **Практический вывод**
# >Если строить модель/портрет риска, то главный вклад ожидаемо дадут: **employment_years + salary**, затем **level**, затем **supervisor_evaluation**. Остальные признаки — скорее “добавочные”.
# >- Для модели важно корректно кодировать категориальные признаки и учитывать дисбаланс классов при выборе метрики (например, ROC-AUC/F1) и стратегии обучения.

# %% [markdown]
# ### Портрет «уволившегося сотрудника» (`quit = yes`)
#
# #### 👤 Кто чаще увольняется
# - **Уровень:** чаще всего увольняется сотрудник уровня **junior** (доля junior — около **89%**, middle — ~10%, senior — ~2%).
# - **Стаж:** уволившиеся чаще имеют **небольшой стаж (1–3 года)** — распределение `employment_years` смещено влево.
# - **Зарплата:** у уволившихся **зарплата ниже**, чем у оставшихся (распределение `salary` заметно смещено к меньшим значениям).
# - **Оценка руководителя:** у уволившихся в среднем **ниже** `supervisor_evaluation`.
#
# ---
#
# #### 🧩 Условия и поведение *(у `quit=yes` против `quit=no`)*
# - **Нагрузка (`workload`):** уволившиеся чаще имеют **низкую нагрузку** (`low` ≈ **46%** против ≈ 24%).
# - **Повышения (`last_year_promo`):** среди уволившихся почти **нет повышенных** за последний год (`yes` ≈ **0.09%** против ≈ 3.9%).
# - **Нарушения (`last_year_violations`):** уволившиеся чаще имеют **нарушения** за последний год (`yes` ≈ **20%** против ≈ 11%).
#
# ---
#
# #### 🏢 Где работает уволившийся сотрудник
# - **Департамент (`dept`)** различается слабее, чем `level/workload`.
#   Наиболее заметно: в `technology` доля уволившихся **чуть выше**, чем у оставшихся; в `hr` — **чуть ниже**.
#   В целом увольняются сотрудники из тех же департаментов, что и остаются, без резких перекосов.
#
# ---
#
# #### ✅ Итоговый портрет
# **Типичный уволившийся сотрудник** — это: **junior**, со **стажем 1–3 года**, с **ниже средней зарплатой** и **более низкой оценкой руководителя**, чаще с **низкой загрузкой**, без **повышения** за последний год, и с **более высокой вероятностью нарушений**.
#
# > Практический вывод для HR: зона риска — **junior с низкой нагрузкой, низкой зарплатой/оценкой и без карьерного прогресса**, особенно при наличии нарушений.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Отлично, молодец, верно выполнено!
#
# Действительно, в случае сравнения - анализ нужно сделать с помощью относительных величин - оперировать абсолютными величинами не всегда удобно, так как в зависимости от масштаба исследования (компания на 100 человек и компания на 100 000 человек, например) результаты могут быть более или менее интерпретируемыми. Для категориальных/дискретных признаков мы можем использовать **value_counts(normalize=True)**, для непрерывных также стоит посчитать и сравнить средние.
#
# **(ТЕОРИЯ) в зависимости от типа признака:**
#
# - Для анализа распределения **непрерывых величин** (у нас это например `salary`) стоит использовать нормированную гистограмму (например, `shs.histplot()` с параметрами `stat='density', common_norm=False` или `sns.kdeplot()`): гистограммы такого типа позволяют нивелировать разницу в размерах выборок при анализе распределений. Обрати также внимание, что при использовании нормированных гистограмм по оси Y будет уже не частота значений, а плотность распределения.
#
# - Для анализа распределения **дискретных величин** (у нас это например `supervisor_evaluation` и `employment_years`) нужен тип графиков, который на каждое уникальные значение признака строит свою корзину. Например, можно использовать `sns.countplot` или `plot(kind='bar')`.
# </div>

# %%
# 1) объединяем test_features + оба таргета
test_full = (
    test_features[[ID_COL]]
    .merge(test_target[[ID_COL, SAT_COL]], on=ID_COL, how="left")
    .merge(test_target_quit[[ID_COL, QUIT_COL]], on=ID_COL, how="left")
)

# 2) чистим данные для сравнения
tmp = test_full.dropna(subset=[SAT_COL, QUIT_COL]).copy()
tmp[SAT_COL] = tmp[SAT_COL].astype(float).clip(0, 1)
tmp[QUIT_COL] = tmp[QUIT_COL].astype(str).str.strip().str.lower()

# 3) сводка по группам
summary = tmp.groupby(QUIT_COL)[SAT_COL].agg(
    count="count",
    mean="mean",
    median="median",
    std="std",
    q25=lambda x: x.quantile(0.25),
    q75=lambda x: x.quantile(0.75),
).round(4)

print("\nСводка job_satisfaction_rate по quit (test):")
display(summary)

# 4) распределения: наложение (плотность)
vals_no  = tmp.loc[tmp[QUIT_COL] == "no",  SAT_COL]
vals_yes = tmp.loc[tmp[QUIT_COL] == "yes", SAT_COL]

edges = np.histogram_bin_edges(tmp[SAT_COL], bins=25)

plt.figure(figsize=(9, 4))
plt.hist(vals_no,  bins=edges, density=True, histtype="step", linewidth=2, label="quit=no")
plt.hist(vals_yes, bins=edges, density=True, histtype="step", linewidth=2, label="quit=yes")
plt.title("job_satisfaction_rate: распределения по quit (test)")
plt.xlabel("job_satisfaction_rate")
plt.ylabel("density")
plt.legend()
plt.tight_layout()
plt.show()

# 5) boxplot
plt.figure(figsize=(6, 4))
plt.boxplot([vals_no.values, vals_yes.values], labels=["quit=no", "quit=yes"], showfliers=False)
plt.title("job_satisfaction_rate по quit (test): boxplot")
plt.ylabel("job_satisfaction_rate")
plt.tight_layout()
plt.show()
# Out:
# Сводка job_satisfaction_rate по quit (test):
#       count    mean  median     std   q25     q75
# quit
# no     1436  0.6120    0.66  0.1994  0.50  0.7600
# yes     564  0.3877    0.37  0.1858  0.24  0.4925

# %% [markdown]
# ### Проверка утверждения: влияет ли удовлетворённость на увольнение
#
# Мы объединили **test_features** с обоими целевыми признаками теста (`job_satisfaction_rate` и `quit`) и сравнили удовлетворённость у тех, кто остался, и у тех, кто уволился.
#
# **Сводные статистики (test):**
# - У сотрудников, которые **остались** в компании, удовлетворённость работой **выше**:
#   среднее значение около **0.61**, а “типичное” (медиана) — около **0.66**.
#   У большинства таких сотрудников удовлетворённость находится примерно в диапазоне **0.50–0.76**.
# - У сотрудников, которые **уволились**, удовлетворённость работой **ниже**:
#   среднее значение около **0.39**, медиана — около **0.37**.
#   Основная масса значений лежит примерно в диапазоне **0.24–0.49**.
#
# **✅ Вывод**
# > Распределение `job_satisfaction_rate` у уволившихся сотрудников **заметно смещено в сторону меньших значений** по сравнению с теми, кто остался. Это подтверждает утверждение аналитиков: **чем ниже удовлетворённость работой, тем выше вероятность увольнения**.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Хорошо! Составлен портрет «ушедшего работника», также есть визуализация и сравнение распределений признака job_satisfaction_rate для ушедших и оставшихся работников, но сравнение без стат теста, "на глаз".
# </div>

# %% [markdown]
# ### 📋 Выводы этапа «Исследовательский анализ данных»
#
# - В данных по увольнениям наблюдается умеренный дисбаланс классов: `quit=no` **~72%**, `quit=yes` **~28%**.
# - Уволившиеся чаще — **junior**, со **стажем 1–3 года**, с **ниже зарплатой** и **ниже оценкой руководителя**.
# - Среди уволившихся заметно чаще встречаются **нарушения**, а **повышения** почти отсутствуют.
# - По тестовым данным подтверждена гипотеза: **низкая удовлетворённость работой связана с увольнением** (у `quit=yes` значения `job_satisfaction_rate` существенно ниже).

# %% [markdown]
# ## Шаг 4. Добавление нового входного признака

# %% [markdown]
# ### 🎯 Задачи шага
#
# Допустим, job_satisfaction_rate и quit действительно связаны и вы получили необходимое значение метрики в первой задаче. Тогда добавьте job_satisfaction_rate, предсказанный лучшей моделью первой задачи, к входным признакам второй задачи.

# %%
# =========================
# Добавляем предсказанный job_satisfaction_rate как признак для задачи quit
# =========================

sat_model=best_model

def _prep_for_predict(df: pd.DataFrame) -> pd.DataFrame:
    # если у тебя в пайплайне уже есть имьютеры — это можно убрать
    return df.replace({pd.NA: np.nan})

# 1) берём признаки для предсказания удовлетворённости (без таргета удовлетворённости и без quit)
X_quit_train = _prep_for_predict(train_quit.drop(columns=[TARGET_QUIT], errors="ignore")).copy()
X_quit_test  = _prep_for_predict(test_features.copy()).copy()

# 2) предсказываем удовлетворённость и клипаем в [0, 1]
sat_pred_train = np.clip(sat_model.predict(X_quit_train), 0, 1)
sat_pred_test  = np.clip(sat_model.predict(X_quit_test),  0, 1)

# 3) добавляем как новый признак во 2-ю задачу
train_quit_aug = train_quit.copy()
test_features_quit_aug = test_features.copy()

train_quit_aug[SAT_COL] = sat_pred_train
test_features_quit_aug[SAT_COL] = sat_pred_test
# Out:
# /opt/conda/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:188: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# ## Шаг 5. Подготовка данных

# %% [markdown]
# ### 🎯 Задачи шага
#
# Подготовьте признаки так же, как и в первой задаче: выполните подготовку в пайплайне, дополнив пайплайн предобработки. При кодировании учитывайте особенности признаков и моделей и используйте как минимум два кодировщика.

# %%
X_train_quit = train_quit_aug.drop(columns=[TARGET_QUIT], errors="ignore").copy()
y_train_quit = train_quit_aug[TARGET_QUIT].astype(str).str.strip().str.lower()

X_test_quit = test_features_quit_aug.copy()

# id не используем в модели
#X_train_quit = X_train_quit.drop(columns=[ID_COL], errors="ignore")
#X_test_quit  = X_test_quit.drop(columns=[ID_COL], errors="ignore")

# =========================
# Колонки по типам
# =========================
ordinal_cols = [c for c in ["level", "workload"] if c in X_train_quit.columns]
binary_cols  = [c for c in ["last_year_promo", "last_year_violations"] if c in X_train_quit.columns]
nominal_cols = [c for c in ["dept"] if c in X_train_quit.columns]

num_cols = X_train_quit.select_dtypes(include="number").columns.tolist()

# бин+номинал кодируем OHE
cat_for_ohe = [c for c in (binary_cols + nominal_cols) if c in X_train_quit.columns]

# =========================
# Preprocessor: пропуски + неизвестные категории внутри пайплайна
# =========================
transformers = []

# 1) числовые: имьютация медианой
if num_cols:
    transformers.append((
        "num",
        Pipeline([
            # важно: imputers сами корректно обрабатывают np.nan
            ("imputer", SimpleImputer(strategy="median")),
        ]),
        num_cols
    ))

# 2) порядковые: most_frequent + OrdinalEncoder
if ordinal_cols:
    ord_categories = []
    if "level" in ordinal_cols:
        ord_categories.append(["junior", "middle", "senior"])
    if "workload" in ordinal_cols:
        ord_categories.append(["low", "medium", "high"])

    transformers.append((
        "ord",
        Pipeline([
            ("imputer", SimpleImputer(strategy="most_frequent")),
            ("encoder", OrdinalEncoder(
                categories=ord_categories,
                handle_unknown="use_encoded_value",
                unknown_value=-1  # все новые/неизвестные категории -> -1
            )),
        ]),
        ordinal_cols
    ))

# 3) бинарные + номинальные: most_frequent + OneHotEncoder
if cat_for_ohe:
    transformers.append((
        "ohe",
        Pipeline([
            ("imputer", SimpleImputer(strategy="most_frequent")),
            ("encoder", OneHotEncoder(drop="first", handle_unknown="ignore")),
        ]),
        cat_for_ohe
    ))

preprocessor_quit = ColumnTransformer(
    transformers=transformers,
    remainder="drop"
)

#_ = preprocessor_quit.fit_transform(X_train_quit)

print("Preprocessor_quit создан (пропуски + unknown обрабатываются внутри).")
print("Числовые:", num_cols)
print("Порядковые:", ordinal_cols)
print("OHE:", cat_for_ohe)


# y_test синхронизируем по id
y_test_quit = (
    test_features_quit_aug[[ID_COL]]
    .merge(test_target_quit[[ID_COL, QUIT_COL]], on=ID_COL, how="left")[QUIT_COL]
)

y_train_bin = (y_train_quit == "yes").astype(int)
y_test_bin  = (y_test_quit.astype(str).str.strip().str.lower() == "yes").astype(int).to_numpy()
# Out:
# Preprocessor_quit создан (пропуски + unknown обрабатываются внутри).
# Числовые: ['id', 'employment_years', 'supervisor_evaluation', 'salary', 'job_satisfaction_rate']
# Порядковые: ['level', 'workload']
# OHE: ['last_year_promo', 'last_year_violations', 'dept']

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# ![image.png](attachment:image.png)
#
# Это ошибка. В ТЗ недвусмысленно Заказчиком определено как следует поступать с пропусками:
# </div>
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Исправил код</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Исправлено.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# ![image.png](attachment:image.png)
#
# Для test выборки значения (ни пропуски, ни дубликаты, ни ошибки) удалять/обрабатывать "вручную" нельзя - эта выборка имитирует реальный поток, в котором модели нужно будет работать со всеми наблюдениями. Ты в приницпе, в реальной жизни, не знаешь какие данные поступят "на вход" разработанной тобой модели (а эти данные, которые будут поступать и по которым твоя модель должна отработать и сделать predict и есть полный аналог тестовой выборки).
#
# Пропуски и ошибки (если они поступают "на вход" ML-модели) **следует обработать в пайплайне**, настроив соответствующим образом работу кодировщиков для новых значений в признаках.
#
# Дубликаты (если они поступают "на вход" ML-модели) - это записи по которым твоя модель должна сделать предсказания.
#
# Да, да, да, это тестовая выборка. С ней работает **только** модель. Удалить/исправить она ничего не может в её данных, но выполнить transform и сделать predict - может. Ну а если в модели корректно сконфигурированы кодировщики (например OneHotEncoder / OrdinalEncoder), то обработка некоторых гипотетических "ошибок" в тестовой выборке и так будет выполнена.
# </div>
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Исправил код, спасибо))</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Исправлено.
# </div>

# %% [markdown]
# ## Шаг 6. Обучение модели

# %% [markdown]
# ### 🎯 Задачи шага
#
# Обучите как минимум три модели. Как минимум для двух из них подберите гиперпараметры. Проверьте качество лучшей модели.
# Метрика оценки качества в этой задаче — ROC-AUC. Критерий успеха: ROC-AUC ≥ 0.91 на тестовой выборке. Напомним: отбор признаков часто помогает улучшить метрику.

# %% [markdown]
# ### Обучаем модель

# %%
step("Настройка моделей")

# --- LogisticRegression + GridSearch ---
logreg_pipe = Pipeline([
    ("preprocess", preprocessor_quit),
    ("model", LogisticRegression(max_iter=2000, solver="liblinear", random_state=RANDOM_STATE))
])

param_grid_logreg = {
    "model__C": [0.1, 0.5, 1, 2, 5, 10],
    "model__penalty": ["l1", "l2"],
}

grid_logreg = GridSearchCV(
    estimator=logreg_pipe,
    param_grid=param_grid_logreg,
    scoring="roc_auc",
    cv=5,
    n_jobs=-1,
    error_score="raise"
)
print("LogReg grid size:", len(param_grid_logreg["model__C"]) * len(param_grid_logreg["model__penalty"]), "configs")


# --- DecisionTreeClassifier + GridSearch ---
tree_pipe = Pipeline([
    ("preprocess", preprocessor_quit),
    ("model", DecisionTreeClassifier(random_state=RANDOM_STATE))
])

param_grid_tree = {
    "model__max_depth": [2, 3, 4, 5, 6, None],
    "model__min_samples_split": [2, 5, 10, 20],
    "model__min_samples_leaf": [1, 2, 5, 10],
    "model__criterion": ["gini", "entropy"],
}

grid_tree = GridSearchCV(
    estimator=tree_pipe,
    param_grid=param_grid_tree,
    scoring="roc_auc",
    cv=3,                      # быстрее
    n_jobs=-1,
    pre_dispatch="2*n_jobs",
    error_score="raise"
)

grid_size_tree = (
    len(param_grid_tree["model__max_depth"]) *
    len(param_grid_tree["model__min_samples_split"]) *
    len(param_grid_tree["model__min_samples_leaf"]) *
    len(param_grid_tree["model__criterion"])
)
print("Tree grid size:", grid_size_tree, "configs")


# --- KNN ---
knn_pipe = Pipeline([
    ("preprocess", preprocessor_quit),
    ("model", KNeighborsClassifier(n_neighbors=15))
])
print("KNN params:", knn_pipe.named_steps["model"].get_params())


# =========================
# Обучение (CV)
# =========================
step("Обучение (GridSearchCV)")

timed("grid_logreg.fit", grid_logreg.fit, X_train_quit, y_train_bin)
print("LogReg best params:", grid_logreg.best_params_)
print("LogReg best CV ROC-AUC:", round(grid_logreg.best_score_, 4))

timed("grid_tree.fit", grid_tree.fit, X_train_quit, y_train_bin)
print("Tree best params:", grid_tree.best_params_)
print("Tree best CV ROC-AUC:", round(grid_tree.best_score_, 4))

step("CV-оценка KNN (чтобы сравнивать честно)")
knn_cv_scores = timed(
    "knn cross_val_score",
    cross_val_score,
    knn_pipe, X_train_quit, y_train_bin,
    scoring="roc_auc",
    cv=5,
    n_jobs=-1
)
knn_cv_mean = float(np.mean(knn_cv_scores))
print("KNN CV ROC-AUC:", round(knn_cv_mean, 4))


# =========================
# Выбор лучшей модели ТОЛЬКО по CV
# =========================
step("Выбор лучшей модели по CV")

cv_table = pd.DataFrame([
    {
        "model": "LogisticRegression (grid)",
        "cv_best_roc_auc": float(grid_logreg.best_score_),
        "best_estimator": grid_logreg.best_estimator_,
        "best_params": grid_logreg.best_params_
    },
    {
        "model": "DecisionTreeClassifier (grid)",
        "cv_best_roc_auc": float(grid_tree.best_score_),
        "best_estimator": grid_tree.best_estimator_,
        "best_params": grid_tree.best_params_
    },
    {
        "model": "KNN (fixed)",
        "cv_best_roc_auc": knn_cv_mean,
        "best_estimator": knn_pipe,
        "best_params": {"n_neighbors": 15}
    },
]).sort_values("cv_best_roc_auc", ascending=False).reset_index(drop=True)

display(cv_table[["model", "cv_best_roc_auc", "best_params"]])

best_name  = cv_table.loc[0, "model"]
best_model = cv_table.loc[0, "best_estimator"]
best_cv    = float(cv_table.loc[0, "cv_best_roc_auc"])

print(f"Лучшая модель по CV: {best_name}, CV ROC-AUC = {best_cv:.4f}")
# Out:
# --- Настройка моделей ---
# LogReg grid size: 12 configs
# Tree grid size: 192 configs
# KNN params: {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 15, 'p': 2, 'weights': 'uniform'}
#
# --- Обучение (GridSearchCV) ---
# [TIME] grid_logreg.fit: 12.13 sec
# LogReg best params: {'model__C': 2, 'model__penalty': 'l1'}
# LogReg best CV ROC-AUC: 0.9186
# [TIME] grid_tree.fit: 22.02 sec
# Tree best params: {'model__criterion': 'gini', 'model__max_depth': 6, 'model__min_samples_leaf': 1, 'model__min_samples_split': 20}
# Tree best CV ROC-AUC: 0.9299
#
# --- CV-оценка KNN (чтобы сравнивать честно) ---
# [TIME] knn cross_val_score: 0.22 sec
# KNN CV ROC-AUC: 0.7365
#
# --- Выбор лучшей модели по CV ---
#                            model  cv_best_roc_auc  \
# 0  DecisionTreeClassifier (grid)         0.929936
# 1      LogisticRegression (grid)         0.918640
# 2                    KNN (fixed)         0.736543
#
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# ![image.png](attachment:image.png)
#
# "Тестирование" (проверка метрики на тестовой выборке) для каждой модели - и избыточно и неверно. Нужно выбрать **самую лучшую модель** по результатам на кросс-валидации и "протестировать" только ее.
#
# Вымышленный пример: если возникает ситуация, что на кросс-валидации лучшая catboost, на тесте random forest, стоит ли нам взять random forest как результат? Нет, иначе тестирование теряет статус независимой проверки, и мы просто подгоняем результаты под тестовый набор, но на практике данные не будут ограничены рамками тестовой выборки, поэтому полагаться на произведенный таким образом выбор мы не можем.
# </div>
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Сделал тестирование только на лучшей моделе. Изменил выводы по новым расчётам.</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Исправлено.
# </div>

# %%
# =========================
# Тестируем ТОЛЬКО лучшую модель
# =========================
step("Тестирование ТОЛЬКО лучшей модели")

timed("best_model.fit", best_model.fit, X_train_quit, y_train_bin)

# ROC-AUC на тесте:
# для большинства моделей есть predict_proba; на всякий fallback на decision_function
if hasattr(best_model, "predict_proba"):
    proba_best = timed("best_model.predict_proba", best_model.predict_proba, X_test_quit)[:, 1]
else:
    score_best = timed("best_model.decision_function", best_model.decision_function, X_test_quit)
    proba_best = (score_best - score_best.min()) / (score_best.max() - score_best.min() + 1e-9)

roc_best = timed("roc_auc_score(best)", roc_auc_score, y_test_bin, proba_best)

print(f"TEST ROC-AUC ({best_name}): {roc_best:.4f}")
print("Критерий успеха (ROC-AUC >= 0.91):", "ВЫПОЛНЕН ✅" if roc_best >= 0.91 else "НЕ ВЫПОЛНЕН ❌")

print("\nПараметры шага 'model' лучшей модели:")
display(pd.Series(best_model.named_steps["model"].get_params()).sort_index())


# =========================
# ROC-кривая (ТОЛЬКО для лучшей модели)
# =========================
step("ROC-кривая (лучшая модель)")

plt.figure(figsize=(6, 5))
RocCurveDisplay.from_predictions(y_test_bin, proba_best, name=best_name)
plt.title("ROC-кривая на тестовой выборке (лучшая модель)")
plt.tight_layout()
plt.show()
# Out:
# --- Тестирование ТОЛЬКО лучшей модели ---
# [TIME] best_model.fit: 0.03 sec
# [TIME] best_model.predict_proba: 0.01 sec
# [TIME] roc_auc_score(best): 0.00 sec
# TEST ROC-AUC (DecisionTreeClassifier (grid)): 0.9197
# Критерий успеха (ROC-AUC >= 0.91): ВЫПОЛНЕН ✅
#
# Параметры шага 'model' лучшей модели:
# /opt/conda/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:188: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# ccp_alpha                    0.0
# class_weight                None
# criterion                   gini
# max_depth                      6
# max_features                None
# max_leaf_nodes              None
# min_impurity_decrease        0.0
# min_samples_leaf               1
# min_samples_split             20
# min_weight_fraction_leaf     0.0
# random_state                  42
# splitter                    best
# dtype: object
# ...

# %% [markdown]
# ### Рассчитаем важность признаков через **SHAP**

# %%
preprocess = best_model.named_steps["preprocess"]
model = best_model.named_steps["model"]

X_test_tr = preprocess.transform(X_test_quit)
feature_names = get_feature_names_quit(preprocess)

rng = np.random.RandomState(42)
exp_size = min(500, X_test_tr.shape[0])
exp_idx  = rng.choice(X_test_tr.shape[0], size=exp_size, replace=False)
X_exp = to_dense(X_test_tr[exp_idx])

explainer = shap.TreeExplainer(model)
sv = explainer.shap_values(X_exp)

# бинарная классификация: list [class0, class1] -> берём класс 1 (quit=yes)
if isinstance(sv, list):
    sv = sv[1]

sv = np.asarray(sv)

if sv.ndim == 3:
    if sv.shape[2] == 2:                 # (n, p, 2) -> берём вклад для positive class
        sv = sv[:, :, 1]
    elif sv.shape[1] == sv.shape[2]:     # (n, p, p) -> interaction -> берём диагональ
        sv = np.diagonal(sv, axis1=1, axis2=2)

# защита от рассинхрона (имена/матрица)
p = min(sv.shape[1], X_exp.shape[1], len(feature_names))
sv = sv[:, :p]
X_plot = X_exp[:, :p]
fn = feature_names[:p]

print("X:", X_plot.shape, "| SHAP:", sv.shape, "| features:", len(fn))

# --- bar ---
shap.summary_plot(
    sv, X_plot,
    feature_names=fn,
    plot_type="bar",
    max_display=14,
    show=False,
    plot_size=(28, 18)
)
ax = plt.gca()
ax.set_title("SHAP: важность признаков (bar)", fontsize=20)
ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)
ax.set_xlabel(ax.get_xlabel(), fontsize=20)  # подпись оси X
plt.tight_layout()
plt.show()

# --- beeswarm ---
shap.summary_plot(
    sv, X_plot,
    feature_names=fn,
    max_display=14,
    show=False,
    plot_size=(28, 18)
)
ax = plt.gca()
ax.set_title("SHAP: распределение вкладов (beeswarm)", fontsize=20)
ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)
ax.set_xlabel(ax.get_xlabel(), fontsize=20)
# цветовая шкала (справа) тоже подпись/тики можно увеличить
cbar_ax = plt.gcf().axes[-1]          # обычно последний Axes — colorbar
cbar_ax.tick_params(labelsize=12)
cbar_ax.set_ylabel("Feature value", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:188: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# X: (500, 13) | SHAP: (500, 13) | features: 13

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Молодец, здесь ты делаешь то, что я редко встречаю в этих проектах (я про визуализацию признаков, которые модель "посчитала" важными. Почему их анализ важен и полезен (несколько причин, почему важно тщательно "рассматривать" признаки):
#
# 1. **Информативность**: Признаки содержат информацию, которая помогает модели делать предсказания. Некоторые признаки могут быть более информативными, чем другие, и могут иметь сильное влияние на результаты модели. Понимание, какие признаки являются наиболее информативными, поможет сосредоточить усилия на сборе и анализе этих признаков, что в конечном итоге может привести к лучшим предсказаниям модели.
#
# 2. **Устранение шума и избыточности**: Некоторые признаки могут содержать шумовую или избыточную информацию, которая может негативно повлиять на работу модели. Анализ и отсев таких признаков помогут улучшить качество модели, устранить возможное переобучение и улучшить ее способность обобщать данные.
#
# 3. **Раскрытие взаимосвязей**: Изучение признаков может помочь обнаружить скрытые взаимосвязи и зависимости в данных. Например, два признака могут быть слабо информативными сами по себе, но в комбинации могут образовывать сильный предиктор. Исследование и понимание взаимосвязей между признаками может привести к созданию более сложных, но более мощных моделей.
#
# 4. **Сокращение размерности**: Некоторые наборы данных могут содержать большое количество признаков, и это может стать проблемой для обучения моделей. Сокращение размерности путем отбора наиболее важных признаков позволяет сократить вычислительную сложность, снизить вероятность переобучения и улучшить интерпретируемость модели.
#
# 5. **Интерпретируемость**: Понимание важности признаков также помогает интерпретировать результаты модели. Если мы знаем, какие признаки оказывают наибольшее влияние на предсказания, мы можем сделать более осознанные выводы и принимать меры на основе результатов
# </div>

# %% [markdown]
# ### 📌 SHAP-анализ важности признаков (лучшая модель: DecisionTreeClassifier)
#
# Модель в первую очередь смотрит на четыре вещи: **уровень сотрудника**, **насколько он доволен работой**, **какая у него загрузка** и **сколько лет он работает в компании**.
#
# Зарплата, отдел, оценка руководителя и нарушения тоже учитываются, но скорее как дополнительные детали — они влияют намного слабее. А повышение в прошлом году и некоторые отделы почти не меняют прогноз.
#
# ---
#
# ***🧠 Что именно «толкает» к увольнению***:
#
# * **Уровень сотрудника (level)** — самый сильный фактор. Сотрудники с более низким уровнем (чаще junior) заметно чаще попадают в группу риска увольнения. Чем выше уровень (middle/senior), тем ниже риск.
#
# * **Удовлетворённость работой (job_satisfaction_rate)** влияет напрямую: низкая удовлетворённость повышает вероятность увольнения, высокая — снижает.
#
# * **Загрузка (workload)** работает как «перекос»: риск увольнения чаще растёт при крайних значениях загрузки (слишком мало или слишком много работы). При более «сбалансированной» загрузке вклад ближе к нулю или снижает риск.
#
# * **Стаж (employment_years)** важен: сотрудники с небольшим стажем чаще увольняются, а с большим стажем — чаще остаются.
#
# * **Остальные признаки** (salary, отдел, оценка руководителя, нарушения, повышение) дают сравнительно небольшой вклад: влияние есть, но оно слабее ключевых факторов и редко становится решающим.
#
# ---
#
# **✅ Итог по интерпретации**
# >Модель в основном опирается на четыре фактора: **уровень сотрудника (level)**, **удовлетворённость работой (job_satisfaction_rate)**, **нагрузку (workload)** и **стаж (employment_years)**.
#
# >Если описать «группу риска» простыми словами: это чаще **junior**, которым **работа нравится меньше**, у которых **небольшой стаж**, и при этом **нагрузка несбалансирована** — либо слишком мало задач, либо слишком много. Обычно с низкой зарплатой.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Экспертный вывод по графикам! Не просто красивые картинки "построена", но описаны те моменты, которые дата-сайентист видит в них!
# </div>

# %% [markdown]
# ## Шаг 7. Выводы

# %% [markdown]
# ### 🎯 Задачи шага
#
# Сделайте промежуточные выводы о том, какая модель справилась лучше и почему.

# %% [markdown]
# ### 📌 Промежуточные выводы по обучению моделей (цель `quit`, метрика ROC-AUC)
#
# - Обучили 3 модели: **LogisticRegression**, **DecisionTreeClassifier**, **KNN**.
#   **Выбор лучшей модели делали по кросс-валидации (CV)**, а **тестировали только победителя**, чтобы тест оставался независимой проверкой.
#
# **Результаты по CV (главный критерий выбора):**
# - **DecisionTreeClassifier (grid)** — **CV ROC-AUC = 0.9299** (лучше всех)
# - **LogisticRegression (grid)** — **CV ROC-AUC = 0.9186**
# - **KNN (fixed)** — **CV ROC-AUC = 0.7365** (заметно слабее)
#
# **Тестирование только лучшей модели:**
# - **DecisionTreeClassifier (grid)** — **TEST ROC-AUC = 0.9197** → критерий **ROC-AUC ≥ 0.91 выполнен ✅**
#   (нормально, что на тесте чуть ниже, чем на CV — тест строже и независим)
#
# **Почему дерево решений оказалось лучше:**
# - Оно лучше «видит» **нелинейные зависимости** и **сочетания признаков** (например, уровень + стаж + загрузка).
# - В текущей постановке **KNN** сильно проседает по качеству на CV (0.7365) — чаще всего из-за чувствительности к размерности/кодированию категорий и метрике расстояния.
#
# **Лучшие гиперпараметры (GridSearch):**
# - **DecisionTreeClassifier**: `criterion='gini'`, `max_depth=6`, `min_samples_split=20`, `min_samples_leaf=1`
# - **LogisticRegression**: `C=2`, `penalty='l1'`
#
# **Время выполнения (по логам):**
# - GridSearch для **дерева**: ~20.4 сек (192 комбинации) — самый долгий шаг
# - GridSearch для **логрег**: ~12.1 сек (12 комбинаций)
# - CV для **KNN**: ~0.20 сек (самый быстрый, но качество низкое)
#
# **Итог:** по CV лучшая модель — **DecisionTreeClassifier**, и на тесте она подтверждает качество (**ROC-AUC = 0.9197**, критерий выполнен).

# %% [markdown]
# ## ✅ Общий вывод по проекту
#
# ### Постановка задачи
# Проект состоит из **двух связанных задач**:
#
# - **Задача 1 (регрессия):** предсказать уровень удовлетворённости сотрудника работой `job_satisfaction_rate` (0–1). Метрика: **SMAPE**, критерий: **SMAPE ≤ 15**.
#
# - **Задача 2 (классификация):** предсказать факт увольнения `quit` (yes/no). Метрика: **ROC-AUC**, критерий: **ROC-AUC ≥ 0.91**.
#
# ---
#
# ### Этапы работы
#
# **1) Загрузка и первичная проверка данных**
# - Загрузили датасеты для обеих задач.
# - Проверили структуру, типы данных, пропуски и дубликаты (в т.ч. дополнительно смотрели «неявные» дубли без `id`).
#
# **2) Очистка и подготовка данных**
# - Обработку пропусков и кодирование перенесли в **пайплайн**, чтобы:
#   - не было утечек,
#   - одинаковая логика применялась к train/test,
#   - новые/неизвестные категории не ломали прод (через настройки энкодеров).
#
# **3) Исследовательский анализ**
# - По задаче `quit` есть **умеренный дисбаланс**: `no ~ 71.8%`, `yes ~ 28.2%`.
# - Сформировали портрет уволившегося и проверили связь `job_satisfaction_rate` ↔ `quit`: у уволившихся удовлетворённость заметно ниже.
#
# **4) Feature engineering (связка задач)**
# - Добавили в признаки второй задачи **предсказанный `job_satisfaction_rate`** из лучшей модели первой задачи как дополнительный сигнал.
#
# **5) Обучение моделей и подбор гиперпараметров**
# **Задача 1 (`job_satisfaction_rate`)**
# - Ridge (CV): **SMAPE = 27.56**, `alpha=300`
# - **DecisionTreeRegressor (CV): SMAPE = 14.568** ✅
#   Лучшие параметры: `max_depth=None`, `min_samples_leaf=2`, `min_samples_split=10`
# - Тестировали **только лучшую по CV** модель:
#   **TEST SMAPE = 13.603** → критерий **SMAPE ≤ 15 выполнен ✅**
#
# **Задача 2 (`quit`)**
# - LogisticRegression (CV ROC-AUC): **0.9186**, `C=2`, `penalty='l1'`
# - **DecisionTreeClassifier (CV ROC-AUC): 0.9299** ✅
#   Лучшие параметры: `criterion='gini'`, `max_depth=6`, `min_samples_split=20`, `min_samples_leaf=1`
# - KNN (CV ROC-AUC): **0.7365** (существенно хуже)
# - Тестировали **только лучшую по CV** модель:
#   **TEST ROC-AUC = 0.9197** → критерий **ROC-AUC ≥ 0.91 выполнен ✅**
#
# **6) Интерпретация**
# - Для лучшей модели по `quit` рассчитали важность признаков через **SHAP**.
# - По глобальной важности модель опирается в первую очередь на: **level**, **(предсказанный) job_satisfaction_rate**, **workload**, **employment_years**.
#   Остальные признаки (зарплата, отдел, оценка руководителя, нарушения/повышение) дают меньший вклад.
#
# ---
#
# ### Итоговые выводы
# - **Задача 1 решена:** лучшая модель **DecisionTreeRegressor**, качество на тесте **SMAPE = 13.603** (критерий выполнен).
# - **Задача 2 решена:** лучшая модель **DecisionTreeClassifier**, качество на тесте **ROC-AUC = 0.9197** (критерий выполнен).
# - Гипотеза подтверждается: **снижение удовлетворённости связано с ростом риска увольнения**.
#
# ---
#
# ### Рекомендации для бизнеса
# - Внедрить регулярный скоринг риска увольнения (например, еженедельно/ежемесячно) и формировать список сотрудников с высоким риском.
# - Использовать SHAP-пояснения для действий: не просто «кто в риске», а **почему** (level/стаж/загрузка/удовлетворённость).
# - Для high-risk сегмента проверить меры удержания:
#   - junior + малый стаж: план развития/наставник/рост ответственности,
#   - перекосы workload: балансировка задач,
#   - работа с факторами удовлетворённости (процессы, коммуникации, условия).

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Сергей, спасибо за качественный и детальный финальный вывод, равно как и за ход проекта - действительно содержащий важные рекомендации бизнесу и подводящий топ-менеджмент Заказчика к идеям по "донастройке" бизнеса.
#
#
# ---
# (СОВЕТ): во всех будущих проектах продолжай уделять внимание финальному выводу (также как и ты это делаешь сейчас!). **ЭТО ОЧЕНЬ ВАЖНО Заказчику**.
#
# Порекомендую ряд вопросов - ответы на которые должны быть всегда "освещены" в выводе:
#
# 1. Какие модели изучали?
#
# 2. Какие результаты получили?
#
# 3. Рекомендуется ли итоговая модель к внедрению?
#
# 4. Какая архитектура модели и способ обработки признаков показали себя лучше всего?
#
# 5. Каковы показатели метрик у лучшей модели?
#
# 6. Какие признаки наиболее важны (feature importances) для модели?
#
# 7. Есть ли перспективы у обучения этой или других моделей? Почему есть? Если нет - что надо сделать чтобы перспективы для решения МЛ-задачи появились?
#
# 8. При наличии приветствуются предложения по дальнейшему развитию этого/аналогичного проекта.
# </div>

# %% [markdown]
# # Результат ревью:
#
# Я отмечаю адекватный уровень твоей программистской подготовки. Ты используешь продвинутые концепции языка Python, библиотеки pandas и одной из основных библиотек машинного обучения sckit-learn. Всё это в целом упрощает твой код и одновременно показывает твой уровень владения инструментами анализа данных и machine learning.
#
# С комментированием никаких проблем нет. Твоих объяснений достаточно для понимания твоими коллегами хода мыслей. Ссылки из брифа проекта в нужных местах также помогают следовать за развитием событий и дают полную информацию касаемо того, что будет происходить в том или ином разделе проекта.
#
# Мне было просто проверять твой проект, потому что он чётко структурирован, с использованием оглавления.
#
# Зелёным цветом я отметил и прокомментировал удачные и элегантные решения, на которые ты можешь опираться в будущих проектах.
#
# Жёлтым цветом я выделил то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас.
#
# Однако есть принципиальные моменты, которые не позволяют мне принять твой проект в его нынешнем состоянии:
#
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# 1. (9 и ниже) Для test выборки любые значения (ни пропуски, ни дубликаты, ни ошибки) "вручную" удалять/обрабатывать нельзя.
#
# 2. (12 и ниже) Ряд признаков в наших данных имеет дискретную природу (например это **employment_years** и **supervisor_evaluation**). Для графического анализа дискретных признаков нужнен тип графиков, который на каждое уникальные значение признака строит свою корзину. Например, можно использовать **sns.countplot** или **.plot(kind='bar')**. Ты же для визуализации их используешь гистограмму.
#
# 3. (15 и ниже) Нормально ли распределены наши признаки? Если нет, то каким методом надо считать коэффициенты корреляции?
#
# 4. (17 и ниже) Обработка пропусков и/или ошибок должна производиться в пайплайне (в соответствии с требованиями Заказчика в ТЗ).
#
# 5. (17 и ниже) Стоит настроить работу энкодера OrdinalEncoder на работу с неизвестными значениями признаков - сейчас энкодер "при встрече с неизвестной категорией " (это может случиться в проде) - будет выбрасывать ошибку.
#
# 6. (19 и ниже) Все модели этого блока оцениваются на тестовой выборке - это преждевременное решение, так как оценка на тестовой выборке - это финальное тестирование для лучшей модели, которая была отобрана в ходе промежуточного тестирования.
#
# </div>
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Все критические замечания учтены и исправлены. Выводы подкорректированы под новые вычисления при их изменениях. Ещё раз спасибо за внимательность и тщательное ревью!</font>
# </div>
#
#
# Эти моменты требуют твоего внимания. Комментарии по ним помечены красным цветом.
#
# Подводя итог: хорошая работа на самом-то деле, молодец! Есть несколько моментов к исправлению, но уверен, что они не вызовут у тебя сложностей. После доработки обязательно проверь комментарии и выводы. Их нужно будет скорректировать. Жду доработанную версию проекта на повторное ревью.

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Всегда рад помочь коллеге!
# </div>
